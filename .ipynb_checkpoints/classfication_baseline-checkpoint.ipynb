# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

np.random.seed(601)

# %% [markdown]
# ## 1. 데이터 불러오기

# %%
train = pd.read_csv('data/titanic_train.csv')
train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ## 2. EDA & 전처리

# %%
print('[shape]\t',train.shape)
print('\n[info]\n')
train.info()
# Out:
# [shape]	 (891, 12)
#
# [info]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### 형변환

# %%
df_type = pd.DataFrame(train.dtypes).reset_index()
df_type.columns = ['col','type']
df_type
# Out:
#             col     type
# 0   PassengerId    int64
# 1      Survived    int64
# 2        Pclass    int64
# 3          Name   object
# 4           Sex   object
# 5           Age  float64
# 6         SibSp    int64
# 7         Parch    int64
# 8        Ticket   object
# 9          Fare  float64
# 10        Cabin   object
# 11     Embarked   object

# %% [markdown]
# #### objects 형

# %%
df_type[df_type.type == 'object']
# Out:
#          col    type
# 3       Name  object
# 4        Sex  object
# 8     Ticket  object
# 10     Cabin  object
# 11  Embarked  object

# %%
train.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                           Name  \
# count    891.000000  891.000000  891.000000                            891
# unique          NaN         NaN         NaN                            891
# top             NaN         NaN         NaN  Allen, Miss. Elisabeth Walton
# freq            NaN         NaN         NaN                              1
# mean     446.000000    0.383838    2.308642                            NaN
# std      257.353842    0.486592    0.836071                            NaN
# min        1.000000    0.000000    1.000000                            NaN
# 25%      223.500000    0.000000    2.000000                            NaN
# 50%      446.000000    0.000000    3.000000                            NaN
# 75%      668.500000    1.000000    3.000000                            NaN
# max      891.000000    1.000000    3.000000                            NaN
#
#          Sex         Age       SibSp       Parch  Ticket        Fare Cabin  \
# count    891  714.000000  891.000000  891.000000     891  891.000000   204
# unique     2         NaN         NaN         NaN     681         NaN   147
# top     male         NaN         NaN         NaN  347082         NaN    G6
# freq     577         NaN         NaN         NaN       7         NaN     4
# mean     NaN   29.699118    0.523008    0.381594     NaN   32.204208   NaN
# std      NaN   14.526497    1.102743    0.806057     NaN   49.693429   NaN
# min      NaN    0.420000    0.000000    0.000000     NaN    0.000000   NaN
# 25%      NaN   20.125000    0.000000    0.000000     NaN    7.910400   NaN
# 50%      NaN   28.000000    0.000000    0.000000     NaN   14.454200   NaN
# 75%      NaN   38.000000    1.000000    0.000000     NaN   31.000000   NaN
# max      NaN   80.000000    8.000000    6.000000     NaN  512.329200   NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %% [markdown]
# ### 데이터 분포 확인

# %%
def df_value_counts(df):
    for col in df.columns:
        print('\n',col)
        print(df[col].value_counts())
        df[col].hist()
        plt.show()
    
df_value_counts(train.iloc[:, 1:])
# Out:
#  Survived
# 0    549
# 1    342
# Name: Survived, dtype: int64
#  Pclass
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
#  Name
# Allen, Miss. Elisabeth Walton                    1
# Knight, Mr. Robert J                             1
# Gee, Mr. Arthur H                                1
# Thayer, Mr. John Borland                         1
# White, Mr. Percival Wayland                      1
#                                                 ..
# Moor, Mrs. (Beila)                               1
# Weisz, Mrs. Leopold (Mathilde Francoise Pede)    1
# Ilett, Miss. Bertha                              1
# Rouse, Mr. Richard Henry                         1
# Fleming, Miss. Margaret                          1
# Name: Name, Length: 891, dtype: int64
#  Sex
# male      577
# female    314
# Name: Sex, dtype: int64
#  Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64
#  SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64
#  Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64
#  Ticket
# 347082         7
# 1601           7
# CA. 2343       7
# CA 2144        6
# 3101295        6
#               ..
# W./C. 14258    1
# 3101276        1
# 36967          1
# 368323         1
# 343276         1
# Name: Ticket, Length: 681, dtype: int64
#  Fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 8.4583      1
# 9.8375      1
# 8.3625      1
# 14.1083     1
# 17.4000     1
# Name: Fare, Length: 248, dtype: int64
#  Cabin
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F33            3
# F2             3
#               ..
# F E69          1
# A16            1
# F G63          1
# C95            1
# E34            1
# Name: Cabin, Length: 147, dtype: int64
#  Embarked
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# ### 결측치 처리

# %%
# NULL 확인 
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.isna().sum()/train.shape[0]
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %% [markdown]
# #### Age - 20%

# %%
train['Age'].fillna(train['Age'].mean(),inplace=True)

# %%
train.Age = train.Age.astype('int')

# %% [markdown]
# #### Cabin - 77% => drop

# %%
train.drop('Cabin', axis=1, inplace=True)

# %% [markdown]
# #### Embarked - 0.002%

# %%
train['Embarked'].value_counts().index
# Out:
# Index(['S', 'C', 'Q'], dtype='object')

# %%
plt.pie(train['Embarked'].value_counts(), labels=train['Embarked'].value_counts().index, autopct='%.1f%%')
plt.show()

# %%
train['Embarked'].fillna('S',inplace=True)

# %%
train.isna().sum().sum()
# Out:
# 0

# %%
# Name

# %%
train['Initial'] = train.Name.str.extract('([A-Za-z]+)\.')

# %%
train.drop('Name', axis=1, inplace=True)

# %%
train.isna().sum().sum() # 결측치 처리
# Out:
# 0

# %% [markdown]
# ### 이상치

# %% [markdown]
# def get_outlier(df=None, column=None, weight=1.5):
#     # fraud에 해당하는 column 데이터만 추출, 1/4 분위와 3/4 분위 지점을 np.percentile로 구함.
#
#     fraud = df[column]
#     quantile_25 = np.percentile(fraud.values, 25)
#     quantile_75 = np.percentile(fraud.values, 75)
#
#     # IQR을 구하고, IQR에 1.5를 곱하여 최대값과 최소값 지점 구함.
#     iqr = quantile_75 - quantile_25
#     iqr_weight = iqr * weight
#     lowest_val = quantile_25 - iqr_weight
#     highest_val = quantile_75 + iqr_weight
#
#     # 최대값 보다 크거나, 최소값 보다 작은 값을 아웃라이어로 설정하고 DataFrame index 반환.
#     outlier_index = fraud[(fraud < lowest_val) | (fraud > highest_val)].index
#
#     return outlier_index

# %%
fig,ax = plt.subplots(1,3, figsize=(18,4))
train.Age.hist(ax=ax[0])
train.Fare.hist(ax=ax[1])
np.log1p(train.Fare).hist(ax=ax[2])
# Out:
# <AxesSubplot:>

# %%
train.Fare = np.log1p(train.Fare)

# %% [markdown]
# ### 카테고리 타입 -> 변환 대상

# %%
train
# Out:
#      PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch  \
# 0              1         0       3    male   22      1      0
# 1              2         1       1  female   38      1      0
# 2              3         1       3  female   26      0      0
# 3              4         1       1  female   35      1      0
# 4              5         0       3    male   35      0      0
# ..           ...       ...     ...     ...  ...    ...    ...
# 886          887         0       2    male   27      0      0
# 887          888         1       1  female   19      0      0
# 888          889         0       3  female   29      1      2
# 889          890         1       1    male   26      0      0
# 890          891         0       3    male   32      0      0
#
#                Ticket      Fare Embarked Initial
# 0           A/5 21171  2.110213        S      Mr
# 1            PC 17599  4.280593        C     Mrs
# 2    STON/O2. 3101282  2.188856        S    Miss
# 3              113803  3.990834        S     Mrs
# 4              373450  2.202765        S      Mr
# ..                ...       ...      ...     ...
# 886            211536  2.639057        S     Rev
# 887            112053  3.433987        S    Miss
# 888        W./C. 6607  3.196630        S    Miss
# 889            111369  3.433987        C      Mr
# 890            370376  2.169054        Q      Mr
#
# [891 rows x 11 columns]

# %%
train.Pclass = train.Pclass.astype('object')

# %%
train = pd.get_dummies(train, columns=['Pclass','Sex','Embarked','Initial'], drop_first=True)

# %% [markdown]
# # 전처리
# * 1. 스케일링과 정규화(StandardScaler, MinMaxScaler)
#
# * 3. 1 보다 많이 사용되는 **로그 변환**

# %% [markdown]
# * train 왜곡

# %%
from scipy.stats import skew

# object가 아닌 숫자형 피쳐의 컬럼 index 객체 추출.
features_index = train.dtypes[train.dtypes != 'object'].index

# house_df에 컬럼 index를 [ ]로 입력하면 해당하는 컬럼 데이터 셋 반환. apply lambda로 skew( )호출 
skew_features = train[features_index].apply(lambda x : skew(x))

# skew 정도가 1 이상인 컬럼들만 추출. 
skew_features_top = skew_features[skew_features > 1]
#print(skew_features_top.sort_values(ascending=False))

# 왜곡도가 1인 피처들은 로그 변환 적용하고 다시 하이퍼 파라미터 튜닝 후 재 학습/예측/평가
#train[skew_features_top.index] = np.log1p(train[skew_features_top.index])

# %% [markdown]
# ### 스케일링과 정규화
# * StandardScaler => 평균 0 / 분산 1
#     * SVM, Linear Regression, Logistic Regression (가우시안 분포 가정)
# * MinMaxScaler => 최소 0(음수 포함 시 -1) / 최대 1

# %%
"""
from sklearn.preprocessing import StandardScaler

# StandardScaler객체 생성
scaler = StandardScaler()
# StandardScaler 로 데이터 셋 변환. fit( ) 과 transform( ) 호출.  
scaler.fit(train)
scaled = scaler.transform(train)

#transform( )시 scale 변환된 데이터 셋이 numpy ndarray로 반환되어 이를 DataFrame으로 변환

scaled_df = pd.DataFrame(data=scaled, columns=train.columns)

print('feature 들의 평균 값')
print(scaled_df.mean())
print('\nfeature 들의 분산 값')
print(scaled_df.var())
"""
# Out:
# "\nfrom sklearn.preprocessing import StandardScaler\n\n# StandardScaler객체 생성\nscaler = StandardScaler()\n# StandardScaler 로 데이터 셋 변환. fit( ) 과 transform( ) 호출.  \nscaler.fit(train)\nscaled = scaler.transform(train)\n\n#transform( )시 scale 변환된 데이터 셋이 numpy ndarray로 반환되어 이를 DataFrame으로 변환\n\nscaled_df = pd.DataFrame(data=scaled, columns=train.columns)\n\nprint('feature 들의 평균 값')\nprint(scaled_df.mean())\nprint('\nfeature 들의 분산 값')\nprint(scaled_df.var())\n"

# %%
"""
from sklearn.preprocessing import MinMaxScaler

# MinMaxScaler객체 생성
scaler = MinMaxScaler()
# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.  
scaler.fit(train)
scaled = scaler.transform(train)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
scaled_df = pd.DataFrame(data=scaled, columns=train.columns)
print('feature들의 최소 값')
print(scaled_df.min())
print('\nfeature들의 최대 값')
print(scaled_df.max())
"""
# Out:
# "\nfrom sklearn.preprocessing import MinMaxScaler\n\n# MinMaxScaler객체 생성\nscaler = MinMaxScaler()\n# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.  \nscaler.fit(train)\nscaled = scaler.transform(train)\n\n# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환\nscaled_df = pd.DataFrame(data=scaled, columns=train.columns)\nprint('feature들의 최소 값')\nprint(scaled_df.min())\nprint('\nfeature들의 최대 값')\nprint(scaled_df.max())\n"

# %%
plt.figure(figsize=(18, 18))
corr = train.corr()
sns.heatmap(corr, cmap='RdBu', annot=True)
# Out:
# <AxesSubplot:>

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PassengerId       891 non-null    int64
#  1   Survived          891 non-null    int64
#  2   Age               891 non-null    int32
#  3   SibSp             891 non-null    int64
#  4   Parch             891 non-null    int64
#  5   Ticket            891 non-null    object
#  6   Fare              891 non-null    float64
#  7   Pclass_2          891 non-null    uint8
#  8   Pclass_3          891 non-null    uint8
#  9   Sex_male          891 non-null    uint8
#  10  Embarked_Q        891 non-null    uint8
#  11  Embarked_S        891 non-null    uint8
#  12  Initial_Col       891 non-null    uint8
#  13  Initial_Countess  891 non-null    uint8
#  14  Initial_Don       891 non-null    uint8
#  15  Initial_Dr        891 non-null    uint8
#  16  Initial_Jonkheer  891 non-null    uint8
#  17  Initial_Lady      891 non-null    uint8
#  18  Initial_Major     891 non-null    uint8
#  19  Initial_Master    891 non-null    uint8
#  20  Initial_Miss      891 non-null    uint8
#  21  Initial_Mlle      891 non-null    uint8
#  22  Initial_Mme       891 non-null    uint8
#  23  Initial_Mr        891 non-null    uint8
#  24  Initial_Mrs       891 non-null    uint8
#  25  Initial_Ms        891 non-null    uint8
#  26  Initial_Rev       891 non-null    uint8
#  27  Initial_Sir       891 non-null    uint8
# dtypes: float64(1), int32(1), int64(4), object(1), uint8(21)
# memory usage: 63.6+ KB

# %% [markdown]
# * ! 모두 숫자형으로 변환이 완료 되었는가?
#
# ## 3. 모델링

# %% [markdown]
# ### 학습 데이터와 테스트 데이터 세트로 분리

# %%
target = train.Survived

# %%
train.drop(['PassengerId','Survived','Ticket'], axis=1, inplace=True)

# %%
from statsmodels.api import OLS
OLS(target, train).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Survived   R-squared (uncentered):                   0.660
# Model:                            OLS   Adj. R-squared (uncentered):              0.651
# Method:                 Least Squares   F-statistic:                              67.38
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):                   1.18e-183
# Time:                        09:59:35   Log-Likelihood:                         -356.50
# No. Observations:                 891   AIC:                                      763.0
# Df Residuals:                     866   BIC:                                      882.8
# Df Model:                          25
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Age                 -0.0031      0.001     -2.675      0.008      -0.005      -0.001
# SibSp               -0.0778      0.014     -5.586      0.000      -0.105      -0.050
# Parch               -0.0556      0.019     -2.992      0.003      -0.092      -0.019
# Fare                 0.0552      0.022      2.484      0.013       0.012       0.099
# Pclass_2            -0.0990      0.048     -2.060      0.040      -0.193      -0.005
# Pclass_3            -0.2436      0.050     -4.864      0.000      -0.342      -0.145
# Sex_male            -0.2134      0.277     -0.770      0.442      -0.757       0.331
# Embarked_Q          -0.0021      0.054     -0.038      0.969      -0.109       0.105
# Embarked_S          -0.0515      0.034     -1.517      0.130      -0.118       0.015
# Initial_Col          0.7292      0.375      1.943      0.052      -0.008       1.466
# Initial_Countess     0.9076      0.384      2.365      0.018       0.155       1.661
# Initial_Don          0.1528      0.455      0.336      0.737      -0.740       1.046
# Initial_Dr           0.6419      0.273      2.354      0.019       0.107       1.177
# Initial_Jonkheer     0.3833      0.458      0.838      0.403      -0.515       1.282
# Initial_Lady         1.0231      0.379      2.702      0.007       0.280       1.766
# Initial_Major        0.7294      0.375      1.943      0.052      -0.007       1.466
# Initial_Master       1.1119      0.280      3.971      0.000       0.562       1.661
# Initial_Miss         0.8679      0.107      8.145      0.000       0.659       1.077
# Initial_Mlle         0.8493      0.276      3.080      0.002       0.308       1.391
# Initial_Mme          0.8402      0.379      2.216      0.027       0.096       1.584
# Initial_Mr           0.5573      0.273      2.044      0.041       0.022       1.093
# Initial_Mrs          0.9615      0.113      8.481      0.000       0.739       1.184
# Initial_Ms           1.0921      0.382      2.862      0.004       0.343       1.841
# Initial_Rev          0.3534      0.313      1.130      0.259      -0.260       0.967
# Initial_Sir          1.2200      0.456      2.675      0.008       0.325       2.115
# ==============================================================================
# Omnibus:                       42.398   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.589
# Skew:                           0.531   Prob(JB):                     4.64e-11
# Kurtosis:                       3.393   Cond. No.                     2.32e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from sklearn.model_selection import train_test_split, KFold
X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.2, shuffle=True\
                                                    , stratify=target, random_state=42)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (712, 25) (179, 25) (712,) (179,)

# %% [markdown]
# ### SMOTE 오버 샘플링

# %%
"""
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=0)
X_train_over, y_train_over = smote.fit_sample(X_train, y_train)
print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트: ', X_train.shape, y_train.shape)
print('SMOTE 적용 후 학습용 피처/레이블 데이터 세트: ', X_train_over.shape, y_train_over.shape)
print('SMOTE 적용 후 레이블 값 분포: \n', pd.Series(y_train_over).value_counts())
"""
# Out:
# "\nfrom imblearn.over_sampling import SMOTE\n\nsmote = SMOTE(random_state=0)\nX_train_over, y_train_over = smote.fit_sample(X_train, y_train)\nprint('SMOTE 적용 전 학습용 피처/레이블 데이터 세트: ', X_train.shape, y_train.shape)\nprint('SMOTE 적용 후 학습용 피처/레이블 데이터 세트: ', X_train_over.shape, y_train_over.shape)\nprint('SMOTE 적용 후 레이블 값 분포: \n', pd.Series(y_train_over).value_counts())\n"

# %% [markdown]
# ### 모델 학습

# %%
from sklearn.ensemble import VotingClassifier

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier # xgboost빠름, 성능 좋음, 10,000 이하 과적합 # 인코딩 없이 자동 변환 

from sklearn.linear_model import LogisticRegression # 분류, 희소 영역 분류, 텍스트 분류

# %%
dt_clf = DecisionTreeClassifier(criterion='gini', # 'entropy'
                                splitter='best', # 'random'
                                max_depth=5,
                                min_samples_split=2,
                                min_samples_leaf=1,
                                min_weight_fraction_leaf=0.0,
                                max_features=None, # 'auto' 'sqrt' 'log2'
                                random_state=11,
                                max_leaf_nodes=None
                               )

rf_clf = RandomForestClassifier(random_state=11) # 배깅(부트스트레핑)

gb_clf = GradientBoostingClassifier(random_state=0) # 과적합에 강, 시간 오래걸림 

ada_clf = AdaBoostClassifier(n_estimators=100)

knn_clf = KNeighborsClassifier(n_neighbors=8)

xgb_clf = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3, random_state=156
                        , min_child_weight=1, colsample_bytree=0.75, reg_alpha=0.03\
                       ,  n_jobs=-1)

lgbm_clf = LGBMClassifier(n_estimators=400, num_leaves=32, sumbsample=0.8, min_child_samples=100,
                          max_depth=128,  n_jobs=-1, boost_from_average=False)

lr_clf = LogisticRegression(random_state=11)

# %% [markdown]
# from statsmodels.api import sm
#
# log_clf = sm.Logit(X_train , y_train))
# classifier = log_clf.fit()
# y_pred = classifier.predict(X_test)
# classifier.summary2()

# %% [markdown]
# ### fit/train

# %%
est = gb_clf

# %%
est.fit(X_train , y_train)

evals = [(X_test, y_test)]
xgb_clf.fit(X_train , y_train,  early_stopping_rounds=400, eval_set=evals, eval_metric="logloss",  verbose=True)
lgbm_clf.fit(X_train, y_train, early_stopping_rounds=100, eval_metric="logloss", 
                 eval_set=evals, verbose=True)
# Out:
# [0]	validation_0-logloss:0.65483
# Will train until validation_0-logloss hasn't improved in 400 rounds.
# [1]	validation_0-logloss:0.61803
# [2]	validation_0-logloss:0.58689
# [3]	validation_0-logloss:0.56811
# [4]	validation_0-logloss:0.54624
# [5]	validation_0-logloss:0.53137
# [6]	validation_0-logloss:0.51894
# [7]	validation_0-logloss:0.50977
# [8]	validation_0-logloss:0.49644
# [9]	validation_0-logloss:0.49226
# [10]	validation_0-logloss:0.48512
# [11]	validation_0-logloss:0.47843
# [12]	validation_0-logloss:0.47080
# [13]	validation_0-logloss:0.46634
# [14]	validation_0-logloss:0.46282
# [15]	validation_0-logloss:0.46055
# [16]	validation_0-logloss:0.45759
# [17]	validation_0-logloss:0.45518
# [18]	validation_0-logloss:0.45357
# [19]	validation_0-logloss:0.45262
# [20]	validation_0-logloss:0.45329
# [21]	validation_0-logloss:0.45265
# [22]	validation_0-logloss:0.45206
# [23]	validation_0-logloss:0.45185
# [24]	validation_0-logloss:0.44817
# [25]	validation_0-logloss:0.44683
# [26]	validation_0-logloss:0.44807
# [27]	validation_0-logloss:0.44626
# [28]	validation_0-logloss:0.44508
# [29]	validation_0-logloss:0.44428
# [30]	validation_0-logloss:0.44574
# [31]	validation_0-logloss:0.44294
# [32]	validation_0-logloss:0.44447
# [33]	validation_0-logloss:0.44604
# [34]	validation_0-logloss:0.44465
# [35]	validation_0-logloss:0.44455
# [36]	validation_0-logloss:0.44547
# [37]	validation_0-logloss:0.44705
# [38]	validation_0-logloss:0.44694
# [39]	validation_0-logloss:0.44717
# [40]	validation_0-logloss:0.44686
# [41]	validation_0-logloss:0.44784
# [42]	validation_0-logloss:0.44598
# [43]	validation_0-logloss:0.44775
# [44]	validation_0-logloss:0.44810
# [45]	validation_0-logloss:0.44860
# [46]	validation_0-logloss:0.44976
# [47]	validation_0-logloss:0.45110
# [48]	validation_0-logloss:0.45179
# [49]	validation_0-logloss:0.45161
# [50]	validation_0-logloss:0.45316
# [51]	validation_0-logloss:0.45351
# [52]	validation_0-logloss:0.45349
# [53]	validation_0-logloss:0.45449
# [54]	validation_0-logloss:0.45404
# [55]	validation_0-logloss:0.45377
# [56]	validation_0-logloss:0.45347
# [57]	validation_0-logloss:0.45407
# [58]	validation_0-logloss:0.45418
# [59]	validation_0-logloss:0.45507
# [60]	validation_0-logloss:0.45612
# [61]	validation_0-logloss:0.45665
# [62]	validation_0-logloss:0.45679
# [63]	validation_0-logloss:0.45771
# [64]	validation_0-logloss:0.45715
# [65]	validation_0-logloss:0.45510
# [66]	validation_0-logloss:0.45535
# [67]	validation_0-logloss:0.45650
# [68]	validation_0-logloss:0.45689
# [69]	validation_0-logloss:0.45680
# [70]	validation_0-logloss:0.45650
# [71]	validation_0-logloss:0.45761
# [72]	validation_0-logloss:0.45743
# [73]	validation_0-logloss:0.45738
# [74]	validation_0-logloss:0.45709
# [75]	validation_0-logloss:0.45841
# [76]	validation_0-logloss:0.45843
# [77]	validation_0-logloss:0.45901
# [78]	validation_0-logloss:0.46010
# [79]	validation_0-logloss:0.46114
# [80]	validation_0-logloss:0.46153
# [81]	validation_0-logloss:0.46164
# [82]	validation_0-logloss:0.46232
# [83]	validation_0-logloss:0.46227
# [84]	validation_0-logloss:0.46293
# [85]	validation_0-logloss:0.46352
# [86]	validation_0-logloss:0.46362
# [87]	validation_0-logloss:0.46406
# [88]	validation_0-logloss:0.46531
# [89]	validation_0-logloss:0.46634
# [90]	validation_0-logloss:0.46696
# [91]	validation_0-logloss:0.46754
# [92]	validation_0-logloss:0.46846
# [93]	validation_0-logloss:0.46856
# [94]	validation_0-logloss:0.46894
# [95]	validation_0-logloss:0.46910
# [96]	validation_0-logloss:0.46922
# [97]	validation_0-logloss:0.46849
# [98]	validation_0-logloss:0.46731
# [99]	validation_0-logloss:0.46799
# [100]	validation_0-logloss:0.46864
# [101]	validation_0-logloss:0.46807
# [102]	validation_0-logloss:0.46699
# [103]	validation_0-logloss:0.46738
# [104]	validation_0-logloss:0.46712
# [105]	validation_0-logloss:0.46666
# [106]	validation_0-logloss:0.46768
# [107]	validation_0-logloss:0.46757
# [108]	validation_0-logloss:0.46826
# [109]	validation_0-logloss:0.46847
# [110]	validation_0-logloss:0.46871
# [111]	validation_0-logloss:0.46944
# [273]	validation_0-logloss:0.48656
# [274]	validation_0-logloss:0.48616
# [275]	validation_0-logloss:0.48655
# [276]	validation_0-logloss:0.48676
# [277]	validation_0-logloss:0.48654
# [278]	validation_0-logloss:0.48715
# [279]	validation_0-logloss:0.48680
# [280]	validation_0-logloss:0.48729
# [281]	validation_0-logloss:0.48835
# [282]	validation_0-logloss:0.48824
# [283]	validation_0-logloss:0.48807
# [284]	validation_0-logloss:0.48855
# [285]	validation_0-logloss:0.48900
# [286]	validation_0-logloss:0.48911
# [287]	validation_0-logloss:0.48957
# [288]	validation_0-logloss:0.48956
# [289]	validation_0-logloss:0.48999
# [290]	validation_0-logloss:0.49076
# [291]	validation_0-logloss:0.49062
# [292]	validation_0-logloss:0.49112
# [293]	validation_0-logloss:0.49146
# [294]	validation_0-logloss:0.49079
# [295]	validation_0-logloss:0.49101
# [296]	validation_0-logloss:0.49106
# [297]	validation_0-logloss:0.49177
# [298]	validation_0-logloss:0.49220
# [299]	validation_0-logloss:0.49209
# [300]	validation_0-logloss:0.49216
# [301]	validation_0-logloss:0.49193
# [302]	validation_0-logloss:0.49166
# [303]	validation_0-logloss:0.49188
# [304]	validation_0-logloss:0.49168
# [305]	validation_0-logloss:0.49161
# [306]	validation_0-logloss:0.49171
# [307]	validation_0-logloss:0.49179
# [308]	validation_0-logloss:0.49195
# [309]	validation_0-logloss:0.49197
# [310]	validation_0-logloss:0.49259
# [311]	validation_0-logloss:0.49306
# [312]	validation_0-logloss:0.49364
# [313]	validation_0-logloss:0.49383
# [314]	validation_0-logloss:0.49428
# [315]	validation_0-logloss:0.49420
# [316]	validation_0-logloss:0.49442
# [317]	validation_0-logloss:0.49486
# [318]	validation_0-logloss:0.49479
# [319]	validation_0-logloss:0.49556
# [320]	validation_0-logloss:0.49673
# [321]	validation_0-logloss:0.49667
# [322]	validation_0-logloss:0.49793
# [323]	validation_0-logloss:0.49806
# [324]	validation_0-logloss:0.49839
# [325]	validation_0-logloss:0.49827
# [326]	validation_0-logloss:0.49824
# [327]	validation_0-logloss:0.49857
# [328]	validation_0-logloss:0.49860
# [329]	validation_0-logloss:0.49934
# [330]	validation_0-logloss:0.49872
# [331]	validation_0-logloss:0.49917
# [332]	validation_0-logloss:0.49885
# [333]	validation_0-logloss:0.49826
# [334]	validation_0-logloss:0.49783
# [335]	validation_0-logloss:0.49764
# [336]	validation_0-logloss:0.49795
# [337]	validation_0-logloss:0.49799
# [338]	validation_0-logloss:0.49782
# [339]	validation_0-logloss:0.49743
# [340]	validation_0-logloss:0.49689
# [341]	validation_0-logloss:0.49761
# [342]	validation_0-logloss:0.49741
# [343]	validation_0-logloss:0.49754
# [344]	validation_0-logloss:0.49864
# [345]	validation_0-logloss:0.49849
# [346]	validation_0-logloss:0.49905
# [347]	validation_0-logloss:0.49885
# [348]	validation_0-logloss:0.49876
# [349]	validation_0-logloss:0.49921
# [350]	validation_0-logloss:0.49916
# [351]	validation_0-logloss:0.49986
# [352]	validation_0-logloss:0.49929
# [353]	validation_0-logloss:0.49907
# [354]	validation_0-logloss:0.49940
# [355]	validation_0-logloss:0.49983
# [356]	validation_0-logloss:0.49971
# [357]	validation_0-logloss:0.50045
# [358]	validation_0-logloss:0.50035
# [359]	validation_0-logloss:0.49988
# [360]	validation_0-logloss:0.50093
# [361]	validation_0-logloss:0.50113
# [362]	validation_0-logloss:0.50153
# [363]	validation_0-logloss:0.50157
# [364]	validation_0-logloss:0.50141
# [365]	validation_0-logloss:0.50162
# [366]	validation_0-logloss:0.50160
# [367]	validation_0-logloss:0.50177
# [368]	validation_0-logloss:0.50216
# [369]	validation_0-logloss:0.50236
# [370]	validation_0-logloss:0.50251
# [371]	validation_0-logloss:0.50263
# [372]	validation_0-logloss:0.50206
# [373]	validation_0-logloss:0.50271
# [374]	validation_0-logloss:0.50235
# [375]	validation_0-logloss:0.50251
# [376]	validation_0-logloss:0.50296
# [377]	validation_0-logloss:0.50342
# [378]	validation_0-logloss:0.50393
# [379]	validation_0-logloss:0.50382
# [380]	validation_0-logloss:0.50397
# [381]	validation_0-logloss:0.50403
# [382]	validation_0-logloss:0.50279
# [383]	validation_0-logloss:0.50411
# [384]	validation_0-logloss:0.50394
# [385]	validation_0-logloss:0.50352
# [386]	validation_0-logloss:0.50243
# [387]	validation_0-logloss:0.50276
# [388]	validation_0-logloss:0.50306
# [389]	validation_0-logloss:0.50330
# [390]	validation_0-logloss:0.50342
# [391]	validation_0-logloss:0.50347
# [392]	validation_0-logloss:0.50358
# [393]	validation_0-logloss:0.50408
# [394]	validation_0-logloss:0.50394
# [395]	validation_0-logloss:0.50279
# [396]	validation_0-logloss:0.50252
# [397]	validation_0-logloss:0.50307
# [398]	validation_0-logloss:0.50341
# [399]	validation_0-logloss:0.50362
# [1]	valid_0's binary_logloss: 0.655802
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.624017
# [3]	valid_0's binary_logloss: 0.598992
# [4]	valid_0's binary_logloss: 0.577095
# [5]	valid_0's binary_logloss: 0.559861
# [6]	valid_0's binary_logloss: 0.544276
# [7]	valid_0's binary_logloss: 0.532232
# [8]	valid_0's binary_logloss: 0.520997
# [9]	valid_0's binary_logloss: 0.511725
# [10]	valid_0's binary_logloss: 0.504634
# [11]	valid_0's binary_logloss: 0.498019
# [12]	valid_0's binary_logloss: 0.493142
# [13]	valid_0's binary_logloss: 0.488449
# [14]	valid_0's binary_logloss: 0.484574
# [15]	valid_0's binary_logloss: 0.481472
# [16]	valid_0's binary_logloss: 0.478672
# [17]	valid_0's binary_logloss: 0.476358
# [18]	valid_0's binary_logloss: 0.474248
# [19]	valid_0's binary_logloss: 0.472873
# [20]	valid_0's binary_logloss: 0.47096
# [21]	valid_0's binary_logloss: 0.470121
# [22]	valid_0's binary_logloss: 0.46874
# [23]	valid_0's binary_logloss: 0.468287
# [24]	valid_0's binary_logloss: 0.467322
# [25]	valid_0's binary_logloss: 0.467605
# [26]	valid_0's binary_logloss: 0.467165
# [27]	valid_0's binary_logloss: 0.46775
# [28]	valid_0's binary_logloss: 0.46751
# [29]	valid_0's binary_logloss: 0.467094
# [30]	valid_0's binary_logloss: 0.467273
# [31]	valid_0's binary_logloss: 0.467601
# [32]	valid_0's binary_logloss: 0.467002
# [33]	valid_0's binary_logloss: 0.467017
# [34]	valid_0's binary_logloss: 0.4668
# [35]	valid_0's binary_logloss: 0.465877
# [36]	valid_0's binary_logloss: 0.465669
# [37]	valid_0's binary_logloss: 0.465576
# [38]	valid_0's binary_logloss: 0.46457
# [39]	valid_0's binary_logloss: 0.464686
# [40]	valid_0's binary_logloss: 0.464101
# [41]	valid_0's binary_logloss: 0.46382
# [42]	valid_0's binary_logloss: 0.463805
# [43]	valid_0's binary_logloss: 0.463914
# [44]	valid_0's binary_logloss: 0.463561
# [45]	valid_0's binary_logloss: 0.463782
# [46]	valid_0's binary_logloss: 0.463565
# [47]	valid_0's binary_logloss: 0.463656
# [48]	valid_0's binary_logloss: 0.462285
# [49]	valid_0's binary_logloss: 0.462562
# [50]	valid_0's binary_logloss: 0.46217
# [51]	valid_0's binary_logloss: 0.46176
# [52]	valid_0's binary_logloss: 0.462045
# [53]	valid_0's binary_logloss: 0.460852
# [54]	valid_0's binary_logloss: 0.460159
# [55]	valid_0's binary_logloss: 0.460489
# [56]	valid_0's binary_logloss: 0.45954
# [57]	valid_0's binary_logloss: 0.45928
# [58]	valid_0's binary_logloss: 0.459219
# [59]	valid_0's binary_logloss: 0.459276
# [60]	valid_0's binary_logloss: 0.458371
# [61]	valid_0's binary_logloss: 0.458601
# [62]	valid_0's binary_logloss: 0.458408
# [63]	valid_0's binary_logloss: 0.457582
# [64]	valid_0's binary_logloss: 0.45663
# [65]	valid_0's binary_logloss: 0.456612
# [66]	valid_0's binary_logloss: 0.456944
# [67]	valid_0's binary_logloss: 0.457406
# [68]	valid_0's binary_logloss: 0.45663
# [69]	valid_0's binary_logloss: 0.456279
# [70]	valid_0's binary_logloss: 0.456051
# [71]	valid_0's binary_logloss: 0.455744
# [72]	valid_0's binary_logloss: 0.455569
# [73]	valid_0's binary_logloss: 0.455786
# [74]	valid_0's binary_logloss: 0.455852
# [75]	valid_0's binary_logloss: 0.455807
# [76]	valid_0's binary_logloss: 0.456048
# [77]	valid_0's binary_logloss: 0.455974
# [78]	valid_0's binary_logloss: 0.456048
# [79]	valid_0's binary_logloss: 0.455571
# [80]	valid_0's binary_logloss: 0.455157
# [81]	valid_0's binary_logloss: 0.454922
# [82]	valid_0's binary_logloss: 0.455266
# [83]	valid_0's binary_logloss: 0.455172
# [84]	valid_0's binary_logloss: 0.455613
# [85]	valid_0's binary_logloss: 0.455279
# [86]	valid_0's binary_logloss: 0.455388
# [87]	valid_0's binary_logloss: 0.455739
# [88]	valid_0's binary_logloss: 0.455691
# [89]	valid_0's binary_logloss: 0.455767
# [90]	valid_0's binary_logloss: 0.455961
# [91]	valid_0's binary_logloss: 0.455851
# [92]	valid_0's binary_logloss: 0.455458
# [93]	valid_0's binary_logloss: 0.455057
# [94]	valid_0's binary_logloss: 0.455002
# [95]	valid_0's binary_logloss: 0.454495
# [96]	valid_0's binary_logloss: 0.454789
# [97]	valid_0's binary_logloss: 0.454218
# [98]	valid_0's binary_logloss: 0.453886
# [99]	valid_0's binary_logloss: 0.454103
# [100]	valid_0's binary_logloss: 0.454261
# [101]	valid_0's binary_logloss: 0.453962
# [102]	valid_0's binary_logloss: 0.454258
# [103]	valid_0's binary_logloss: 0.453925
# [104]	valid_0's binary_logloss: 0.453908
# [105]	valid_0's binary_logloss: 0.453896
# [106]	valid_0's binary_logloss: 0.454013
# [107]	valid_0's binary_logloss: 0.453714
# [108]	valid_0's binary_logloss: 0.453668
# [109]	valid_0's binary_logloss: 0.454171
# [110]	valid_0's binary_logloss: 0.454528
# [111]	valid_0's binary_logloss: 0.454125
# [112]	valid_0's binary_logloss: 0.454131
# [113]	valid_0's binary_logloss: 0.455242
# [114]	valid_0's binary_logloss: 0.454749
# [115]	valid_0's binary_logloss: 0.455141
# [116]	valid_0's binary_logloss: 0.455372
# [117]	valid_0's binary_logloss: 0.455518
# [118]	valid_0's binary_logloss: 0.456638
# [119]	valid_0's binary_logloss: 0.456781
# [120]	valid_0's binary_logloss: 0.456524
# [121]	valid_0's binary_logloss: 0.456259
# [122]	valid_0's binary_logloss: 0.456564
# [123]	valid_0's binary_logloss: 0.456451
# [124]	valid_0's binary_logloss: 0.4562
# [125]	valid_0's binary_logloss: 0.455959
# [126]	valid_0's binary_logloss: 0.456037
# [127]	valid_0's binary_logloss: 0.456473
# [128]	valid_0's binary_logloss: 0.456267
# [129]	valid_0's binary_logloss: 0.457377
# [130]	valid_0's binary_logloss: 0.457778
# [131]	valid_0's binary_logloss: 0.457937
# [132]	valid_0's binary_logloss: 0.457818
# [133]	valid_0's binary_logloss: 0.457679
# [134]	valid_0's binary_logloss: 0.457833
# [135]	valid_0's binary_logloss: 0.457604
# [136]	valid_0's binary_logloss: 0.457382
# [137]	valid_0's binary_logloss: 0.458475
# [138]	valid_0's binary_logloss: 0.458522
# [139]	valid_0's binary_logloss: 0.458659
# [140]	valid_0's binary_logloss: 0.458426
# [141]	valid_0's binary_logloss: 0.458195
# [142]	valid_0's binary_logloss: 0.458459
# [143]	valid_0's binary_logloss: 0.458572
# [144]	valid_0's binary_logloss: 0.45864
# [145]	valid_0's binary_logloss: 0.458904
# [146]	valid_0's binary_logloss: 0.459008
# [147]	valid_0's binary_logloss: 0.459952
# [148]	valid_0's binary_logloss: 0.46103
# [149]	valid_0's binary_logloss: 0.46145
# [150]	valid_0's binary_logloss: 0.461285
# [151]	valid_0's binary_logloss: 0.460996
# [152]	valid_0's binary_logloss: 0.460722
# [153]	valid_0's binary_logloss: 0.460414
# [154]	valid_0's binary_logloss: 0.460325
# [155]	valid_0's binary_logloss: 0.460633
# [156]	valid_0's binary_logloss: 0.460358
# [157]	valid_0's binary_logloss: 0.460688
# [158]	valid_0's binary_logloss: 0.460447
# [159]	valid_0's binary_logloss: 0.46149
# [160]	valid_0's binary_logloss: 0.461457
# [161]	valid_0's binary_logloss: 0.461302
# [162]	valid_0's binary_logloss: 0.461292
# [163]	valid_0's binary_logloss: 0.461708
# [164]	valid_0's binary_logloss: 0.461862
# [165]	valid_0's binary_logloss: 0.462169
# [166]	valid_0's binary_logloss: 0.46216
# [167]	valid_0's binary_logloss: 0.462237
# [168]	valid_0's binary_logloss: 0.461951
# [169]	valid_0's binary_logloss: 0.462074
# [170]	valid_0's binary_logloss: 0.462049
# [171]	valid_0's binary_logloss: 0.462535
# [172]	valid_0's binary_logloss: 0.462529
# [173]	valid_0's binary_logloss: 0.462301
# [174]	valid_0's binary_logloss: 0.462364
# [175]	valid_0's binary_logloss: 0.462165
# [176]	valid_0's binary_logloss: 0.462502
# [177]	valid_0's binary_logloss: 0.462957
# [178]	valid_0's binary_logloss: 0.462722
# [179]	valid_0's binary_logloss: 0.463045
# [180]	valid_0's binary_logloss: 0.463019
# [181]	valid_0's binary_logloss: 0.463322
# [182]	valid_0's binary_logloss: 0.463322
# [183]	valid_0's binary_logloss: 0.463436
# [184]	valid_0's binary_logloss: 0.463401
# [185]	valid_0's binary_logloss: 0.463318
# [186]	valid_0's binary_logloss: 0.463469
# [187]	valid_0's binary_logloss: 0.462899
# [188]	valid_0's binary_logloss: 0.463902
# [189]	valid_0's binary_logloss: 0.463118
# [190]	valid_0's binary_logloss: 0.463522
# [191]	valid_0's binary_logloss: 0.464477
# [192]	valid_0's binary_logloss: 0.46373
# [193]	valid_0's binary_logloss: 0.463851
# [194]	valid_0's binary_logloss: 0.464156
# [195]	valid_0's binary_logloss: 0.463417
# [196]	valid_0's binary_logloss: 0.463339
# [197]	valid_0's binary_logloss: 0.46282
# [198]	valid_0's binary_logloss: 0.462618
# [199]	valid_0's binary_logloss: 0.462729
# [200]	valid_0's binary_logloss: 0.463145
# [201]	valid_0's binary_logloss: 0.463579
# [202]	valid_0's binary_logloss: 0.462901
# [203]	valid_0's binary_logloss: 0.462439
# [204]	valid_0's binary_logloss: 0.462246
# [205]	valid_0's binary_logloss: 0.462367
# [206]	valid_0's binary_logloss: 0.463047
# [207]	valid_0's binary_logloss: 0.46261
# [208]	valid_0's binary_logloss: 0.462414
# Early stopping, best iteration is:
# [108]	valid_0's binary_logloss: 0.453668
# LGBMClassifier(boost_from_average=False, max_depth=128, min_child_samples=100,
#                n_estimators=400, num_leaves=32, sumbsample=0.8)

# %% [markdown]
# ### predict

# %%
from sklearn.metrics import accuracy_score, confusion_matrix\
                            , precision_score, recall_score\
                            , precision_recall_curve\
                            , f1_score, roc_curve, roc_auc_score\
                            , mean_absolute_error
from sklearn.preprocessing import Binarizer
import matplotlib.ticker as ticker

# %%
def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    # ROC-AUC 추가 
    roc_auc = roc_auc_score(y_test, pred_proba, average='macro') # 'macro', 'weighted','samples' 
    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

#pred_proba = grid_dtree.predict_proba(X_test)
#get_clf_eval(y_test, pred, pred_proba[:,1].reshape(-1,1))

# %%
pred = est.predict(X_test)
accuracy = accuracy_score(y_test , pred)
accuracy

w_preds = xgb_clf.predict(X_test)
w_pred_proba = xgb_clf.predict_proba(X_test)[:, 1]
get_clf_eval(y_test , w_preds, w_pred_proba)

l_preds = lgbm_clf.predict(X_test)
l_pred_proba = lgbm_clf.predict_proba(X_test)[:, 1]
get_clf_eval(y_test , l_preds, l_pred_proba)
# Out:
# 오차 행렬
# [[101   9]
#  [ 27  42]]
# 정확도: 0.7989, 정밀도: 0.8235, 재현율: 0.6087,    F1: 0.7000, AUC:0.8450
# 오차 행렬
# [[98 12]
#  [25 44]]
# 정확도: 0.7933, 정밀도: 0.7857, 재현율: 0.6377,    F1: 0.7040, AUC:0.8430

# %%
# DecisionTreeClassifier의 하이퍼 파라미터 추출
print('DecisionTreeClassifier 기본 하이퍼 파라미터:\n', dt_clf.get_params())
# Out:
# DecisionTreeClassifier 기본 하이퍼 파라미터:
#  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': 'deprecated', 'random_state': 11, 'splitter': 'best'}

# %% [markdown]
# 트리 시각화

# %%
"""
from sklearn.tree import export_graphviz
import graphviz

export_graphviz(dt_clf, out_file="tree.dot", class_names=['0','1'] , \
                feature_names = train.columns, impurity=True, filled=True)


with open("tree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)
"""
# Out:
# '\nfrom sklearn.tree import export_graphviz\nimport graphviz\n\nexport_graphviz(dt_clf, out_file="tree.dot", class_names=[\'0\',\'1\'] ,                 feature_names = train.columns, impurity=True, filled=True)\n\n\nwith open("tree.dot") as f:\n    dot_graph = f.read()\ngraphviz.Source(dot_graph)\n'

# %%
def vis_feature_importances_(est):
    ftr_importances_values = est.feature_importances_
    ftr_importances = pd.Series(ftr_importances_values,index=X_train.columns  )
    ftr_top20 = ftr_importances.sort_values(ascending=False)[:20]
    plt.figure(figsize=(8,6))
    plt.title('Feature importances Top 20')
    sns.barplot(x=ftr_top20 , y = ftr_top20.index)
    plt.show()

# %%
# feature importance 추출 
print("Feature importances:\n{0}".format(np.round(gb_clf.feature_importances_, 3)))
# Out:
# Feature importances:
# [0.106 0.021 0.004 0.216 0.003 0.118 0.157 0.001 0.02  0.003 0.    0.001
#  0.002 0.    0.    0.002 0.004 0.002 0.    0.    0.316 0.004 0.    0.022
#  0.   ]

# %%
# feature별 importance 매핑
for name, value in zip(train.columns , gb_clf.feature_importances_):
    print('{0} : {1:.3f}'.format(name, value))
# Out:
# Age : 0.106
# SibSp : 0.021
# Parch : 0.004
# Fare : 0.216
# Pclass_2 : 0.003
# Pclass_3 : 0.118
# Sex_male : 0.157
# Embarked_Q : 0.001
# Embarked_S : 0.020
# Initial_Col : 0.003
# Initial_Countess : 0.000
# Initial_Don : 0.001
# Initial_Dr : 0.002
# Initial_Jonkheer : 0.000
# Initial_Lady : 0.000
# Initial_Major : 0.002
# Initial_Master : 0.004
# Initial_Miss : 0.002
# Initial_Mlle : 0.000
# Initial_Mme : 0.000
# Initial_Mr : 0.316
# Initial_Mrs : 0.004
# Initial_Ms : 0.000
# Initial_Rev : 0.022
# Initial_Sir : 0.000

# %%
# feature importance를 column 별로 시각화 하기 
sns.barplot(x=gb_clf.feature_importances_ , y=train.columns)
# Out:
# <AxesSubplot:>

# %%
vis_feature_importances_(gb_clf)

# %%
# Classifier의 Decision Boundary를 시각화 하는 함수
def visualize_boundary(model, X, y):
    fig,ax = plt.subplots()
    
    # 학습 데이타 scatter plot으로 나타내기
    ax.scatter(X[:, 0], X[:, 1], c=y, s=25, cmap='rainbow', edgecolor='k',
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim_start , xlim_end = ax.get_xlim()
    ylim_start , ylim_end = ax.get_ylim()
    
    # 호출 파라미터로 들어온 training 데이타로 model 학습 . 
    model.fit(X, y)
    # meshgrid 형태인 모든 좌표값으로 예측 수행. 
    xx, yy = np.meshgrid(np.linspace(xlim_start,xlim_end, num=200),np.linspace(ylim_start,ylim_end, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    # contourf() 를 이용하여 class boundary 를 visualization 수행. 
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap='rainbow', clim=(y.min(), y.max()),
                           zorder=1)

visualize_boundary(dt_clf, train[['Sex_male','Pclass_2']].values, target)

# %% [markdown]
# ### GridSearchCV = 교차 검증 + 하이퍼파라미터 튜닝
#
# * 학습 데이터를 GridSearchCV를 이용해 최적 하이퍼 파라미터 튜닝,
# * 별도의 테스트 세트에서 평가
# * n_jobs=-1 모든 CPU 코어 사용
#
#
# * 부스팅 계열 튜닝 방안: learning_rate 를 줄이며 n_estimators 를 크게 하는 것
#     * n_estimators 너무 크면 과적합

# %%
from sklearn.model_selection import GridSearchCV
import time
start_time = time.time()

"""
# DecisionTreeClassifier
params = {'max_depth':[1, 2, 3], 'min_samples_split':[2,3]}
grid_cv = GridSearchCV(dt_clf
                          , param_grid=params
                          , scoring='accuracy'
                          , cv=3
                          , refit=True
                          , return_train_score=True)
"""
"""
# RandomForestClassifier
params = {
    'n_estimators':[100],
    'max_depth' : [6, 8, 10, 12], 
    'min_samples_leaf' : [8, 12, 18 ],
    'min_samples_split' : [8, 16, 20]
}
grid_cv = GridSearchCV(rf_clf , param_grid=params , cv=2, n_jobs=-1
                      , refit=True)
"""
""" 
# GradientBoostingClassifier
params = {
    'n_estimators':[100, 500],
    'learning_rate' : [ 0.05, 0.1]
}
grid_cv = GridSearchCV(gb_clf , param_grid=params , cv=2 ,verbose=1
                      , refit=True)
""" 
""" 
# XGBClassifier
params = {'max_depth':[5, 7] , 'min_child_weight':[1,3] ,'colsample_bytree':[0.5, 0.75] }
grid_cv = GridSearchCV(xgb_clf , param_grid=params
           ,refit=True)
"""            
# LGBMClassifier
params = {'num_leaves': [32, 64 ],
          'max_depth':[128, 160],
          'min_child_samples':[60, 100],
          'subsample':[0.8, 1]}
grid_cv = GridSearchCV(lgbm_clf , param_grid=params
           ,refit=True)
#---------------------------------------------------------------------------#

# DecisionTreeClassifier RandomForestClassifier GradientBoostingClassifier
#grid_cv.fit(X_train , y_train)

# XGBClassifier LGBMClassifier
grid_cv.fit(X_train, y_train, early_stopping_rounds=30, eval_metric="auc",
           eval_set=[(X_train, y_train), (X_test, y_test)])


# Train 데이터로 param_grid의 하이퍼 파라미터들을 순차적으로 학습/평가 .
grid_cv.fit(X_train, y_train)

# GridSearchCV 결과는 cv_results_ 라는 딕셔너리로 저장됨. 이를 DataFrame으로 변환
scores_df = pd.DataFrame(grid_cv.cv_results_)
#scores_df[['params', 'param_max_depth','mean_test_score', 'rank_test_score', 
#           'split0_test_score', 'split1_test_score', 'split2_test_score']]

print('GridSearchCV 최적 파라미터:', grid_cv.best_params_)
print('GridSearchCV 최고 정확도: {0:.4f}'.format(grid_cv.best_score_))

# refit=True로 설정된 GridSearchCV 객체가 fit()을 수행 시 학습이 완료된 Estimator를 내포하고 있으므로 predict()를 통해 예측도 가능. 
pred = grid_cv.predict(X_test)
print('테스트 데이터 세트ㄴ 정확도: {0:.4f}'.format(accuracy_score(y_test,pred)))

print("수행 시간: {0:.1f} 초 ".format(time.time() - start_time))
# Out:
# [1]	valid_0's auc: 0.864657	valid_0's binary_logloss: 0.650016	valid_1's auc: 0.820553	valid_1's binary_logloss: 0.655595
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.864657	valid_0's binary_logloss: 0.614834	valid_1's auc: 0.820553	valid_1's binary_logloss: 0.625263
# [3]	valid_0's auc: 0.864657	valid_0's binary_logloss: 0.585775	valid_1's auc: 0.820553	valid_1's binary_logloss: 0.600515
# [4]	valid_0's auc: 0.865466	valid_0's binary_logloss: 0.561645	valid_1's auc: 0.81996	valid_1's binary_logloss: 0.580014
# [5]	valid_0's auc: 0.865466	valid_0's binary_logloss: 0.541284	valid_1's auc: 0.81996	valid_1's binary_logloss: 0.563261
# [6]	valid_0's auc: 0.870618	valid_0's binary_logloss: 0.523693	valid_1's auc: 0.821014	valid_1's binary_logloss: 0.547387
# [7]	valid_0's auc: 0.870769	valid_0's binary_logloss: 0.508996	valid_1's auc: 0.821937	valid_1's binary_logloss: 0.535581
# [8]	valid_0's auc: 0.869709	valid_0's binary_logloss: 0.496116	valid_1's auc: 0.820092	valid_1's binary_logloss: 0.52419
# [9]	valid_0's auc: 0.869867	valid_0's binary_logloss: 0.485304	valid_1's auc: 0.820751	valid_1's binary_logloss: 0.515957
# [10]	valid_0's auc: 0.870372	valid_0's binary_logloss: 0.475665	valid_1's auc: 0.826416	valid_1's binary_logloss: 0.507772
# [11]	valid_0's auc: 0.870648	valid_0's binary_logloss: 0.467648	valid_1's auc: 0.821673	valid_1's binary_logloss: 0.502096
# [12]	valid_0's auc: 0.870564	valid_0's binary_logloss: 0.460465	valid_1's auc: 0.825494	valid_1's binary_logloss: 0.496602
# [13]	valid_0's auc: 0.877018	valid_0's binary_logloss: 0.452861	valid_1's auc: 0.826087	valid_1's binary_logloss: 0.491338
# [14]	valid_0's auc: 0.876576	valid_0's binary_logloss: 0.447481	valid_1's auc: 0.826219	valid_1's binary_logloss: 0.487524
# [15]	valid_0's auc: 0.876943	valid_0's binary_logloss: 0.441741	valid_1's auc: 0.825692	valid_1's binary_logloss: 0.483838
# [16]	valid_0's auc: 0.876701	valid_0's binary_logloss: 0.437124	valid_1's auc: 0.826087	valid_1's binary_logloss: 0.481618
# [17]	valid_0's auc: 0.877494	valid_0's binary_logloss: 0.432574	valid_1's auc: 0.827668	valid_1's binary_logloss: 0.480119
# [71]	valid_0's auc: 0.929076	valid_0's binary_logloss: 0.330688	valid_1's auc: 0.836891	valid_1's binary_logloss: 0.461465
# [72]	valid_0's auc: 0.929339	valid_0's binary_logloss: 0.330007	valid_1's auc: 0.839921	valid_1's binary_logloss: 0.461066
# [73]	valid_0's auc: 0.929698	valid_0's binary_logloss: 0.329314	valid_1's auc: 0.837945	valid_1's binary_logloss: 0.460919
# [74]	valid_0's auc: 0.930332	valid_0's binary_logloss: 0.328365	valid_1's auc: 0.838999	valid_1's binary_logloss: 0.46147
# [75]	valid_0's auc: 0.930478	valid_0's binary_logloss: 0.327546	valid_1's auc: 0.835968	valid_1's binary_logloss: 0.462504
# [76]	valid_0's auc: 0.930749	valid_0's binary_logloss: 0.326932	valid_1's auc: 0.837022	valid_1's binary_logloss: 0.461292
# [77]	valid_0's auc: 0.931212	valid_0's binary_logloss: 0.326149	valid_1's auc: 0.836495	valid_1's binary_logloss: 0.460954
# [78]	valid_0's auc: 0.931471	valid_0's binary_logloss: 0.325232	valid_1's auc: 0.837681	valid_1's binary_logloss: 0.461211
# Early stopping, best iteration is:
# [48]	valid_0's auc: 0.917887	valid_0's binary_logloss: 0.352538	valid_1's auc: 0.837681	valid_1's binary_logloss: 0.459184
# GridSearchCV 최적 파라미터: {'max_depth': 128, 'min_child_samples': 100, 'num_leaves': 32, 'subsample': 0.8}
# GridSearchCV 최고 정확도: 0.8231
# 테스트 데이터 세트ㄴ 정확도: 0.8101
# 수행 시간: 22.4 초

# %%
# scores_df

#vis_feature_importances_(dt_clf)

#est = dt_clf
#est = rf_clf
est = gb_clf

est.fit(X_train , y_train)
vis_feature_importances_(est)

# %%
from xgboost import plot_importance

fig, ax = plt.subplots(figsize=(10, 12))
# 사이킷런 래퍼 클래스를 입력해도 무방. 
plot_importance(xgb_clf, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
from lightgbm import plot_importance

fig, ax = plt.subplots(figsize=(10, 12))
# 사이킷런 래퍼 클래스를 입력해도 무방. 
plot_importance(lgbm_clf, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# ### 교차검증
#
# * Classifier: StratifiedKFold
# * Regressor: KFold
#
# cross_val_score(estimator,X,y=None,scoring=None,cv='warn',n_jobs=None,verbose=0,fit_params=None)
#
# **cross_val_score = KFold/StratifiedKFold + train_test_split + fit/predict/evaluation**

# %%
from sklearn.model_selection import cross_val_score

"""
scores = cross_val_score(dt_clf , train, target , scoring='accuracy',cv=3)
print('교차 검증별 정확도:',np.round(scores, 4))
print('평균 검증 정확도:', np.round(np.mean(scores), 4))
"""
# Out:
# "\nscores = cross_val_score(dt_clf , train, target , scoring='accuracy',cv=3)\nprint('교차 검증별 정확도:',np.round(scores, 4))\nprint('평균 검증 정확도:', np.round(np.mean(scores), 4))\n"

# %% [markdown]
# # 평가
# * 회귀: Mean(오차(실제값 - 예측값)) : 오차 평균에 기반
# * 분류: 일반적으로 오차에 기반 + **성능 평가 지표**
#     * **이진분류:** 정확도 << 성능 평가 지표
#
# ### 성능평가지표
# * 정확도
#     * 불균형 레이블 모델 부적합
# * 오차행렬
# * 정밀도(Precision): Positive 예측 중 예측과 실제 Positive 일치 비율(양성 예측도)
#     * 실제 Negative를 Positive로 잘못 판단하면 큰 영향이 미치는 경우(ex: 스팸메일)
#     * FN: 실제 Positive 예측 Negative 를 낮추는데 초점
# * 재현율(Recall): Positive 예측 중 실제 Positive 비율(민감도/TPR)
#     * 실제 Positive를 Negative로 잘못 판단하면 큰 영향이 미치는 경우(ex: 암 판단)
#     * FP: 실제 Positive 예측 Positive 를 낮추는데 초점
# * F1 스코어: 정밀도/재현율 치우치지 않을수록 높게 나타남
# * ROC AUC
#
# * predict_proba(): 개별 데이터별로 예측 확률을 반환
#     * 학습이 완료된 사이킷런 Classfier 객체에서 호출 가능

# %%
pred_proba = est.predict_proba(X_test)
pred_proba[:3] # 합하면 1
# Out:
# array([[0.89444736, 0.10555264],
#        [0.88868126, 0.11131874],
#        [0.85487872, 0.14512128]])

# %%
pred_proba[:,1].reshape(-1,1)
# Out:
# array([[0.10555264],
#        [0.11131874],
#        [0.14512128],
#        [0.0873374 ],
#        [0.56038428],
#        [0.41943662],
#        [0.84536606],
#        [0.85786898],
#        [0.79265777],
#        [0.13907304],
#        [0.16896028],
#        [0.12434442],
#        [0.41500453],
#        [0.19379423],
#        [0.09668474],
#        [0.15899383],
#        [0.10210956],
#        [0.12003397],
#        [0.0301622 ],
#        [0.88145493],
#        [0.12003397],
#        [0.90699008],
#        [0.16629717],
#        [0.41943662],
#        [0.09302005],
#        [0.96725514],
#        [0.16896028],
#        [0.28403428],
#        [0.13989255],
#        [0.12950498],
#        [0.16627924],
#        [0.91913857],
#        [0.56967905],
#        [0.07665808],
#        [0.21651595],
#        [0.8741078 ],
#        [0.32502257],
#        [0.10017759],
#        [0.16896028],
#        [0.86003547],
#        [0.59768306],
#        [0.98626178],
#        [0.17309394],
#        [0.86003547],
#        [0.7878742 ],
#        [0.14029367],
#        [0.10710702],
#        [0.36901214],
#        [0.9227222 ],
#        [0.82649923],
#        [0.96094611],
#        [0.41500453],
#        [0.76638237],
#        [0.10096656],
#        [0.73949932],
#        [0.12003397],
#        [0.09673802],
#        [0.63418239],
#        [0.60843574],
#        [0.63418239],
#        [0.53741745],
#        [0.84213071],
#        [0.12716524],
#        [0.08502418],
#        [0.49511514],
#        [0.39124286],
#        [0.96397416],
#        [0.14921646],
#        [0.10632046],
#        [0.10096656],
#        [0.93434893],
#        [0.13671445],
#        [0.7727761 ],
#        [0.95040189],
#        [0.14104321],
#        [0.10537344],
#        [0.14093491],
#        [0.0960548 ],
#        [0.0897586 ],
#        [0.04591907],
#        [0.18220396],
#        [0.06962088],
#        [0.08351047],
#        [0.09302005],
#        [0.7727761 ],
#        [0.31679981],
#        [0.04947653],
#        [0.37527592],
#        [0.16258198],
#        [0.88101774],
#        [0.15082774],
#        [0.15082774],
#        [0.03283152],
#        [0.07856715],
#        [0.37049507],
#        [0.88784963],
#        [0.76868275],
#        [0.16896028],
#        [0.14093491],
#        [0.02452762],
#        [0.17276345],
#        [0.83445966],
#        [0.7727761 ],
#        [0.91769475],
#        [0.07856715],
#        [0.15082774],
#        [0.13758621],
#        [0.07856715],
#        [0.0895734 ],
#        [0.84815463],
#        [0.16896028],
#        [0.08532227],
#        [0.09302005],
#        [0.26800189],
#        [0.8981839 ],
#        [0.16896028],
#        [0.16200852],
#        [0.14559309],
#        [0.09673802],
#        [0.17276345],
#        [0.07856715],
#        [0.58561181],
#        [0.12861084],
#        [0.07310976],
#        [0.10581845],
#        [0.18869014],
#        [0.29544608],
#        [0.33333261],
#        [0.12003397],
#        [0.29093019],
#        [0.59166958],
#        [0.09302005],
#        [0.51992786],
#        [0.03551807],
#        [0.3581625 ],
#        [0.10710702],
#        [0.86370647],
#        [0.16896028],
#        [0.7727761 ],
#        [0.08313571],
#        [0.25656235],
#        [0.14512128],
#        [0.78004208],
#        [0.63968914],
#        [0.1495755 ],
#        [0.11471423],
#        [0.07856715],
#        [0.09949136],
#        [0.91037781],
#        [0.86727546],
#        [0.02452762],
#        [0.15972249],
#        [0.83445966],
#        [0.41775721],
#        [0.10481173],
#        [0.48231728],
#        [0.11291593],
#        [0.09673802],
#        [0.18310405],
#        [0.7420179 ],
#        [0.4574024 ],
#        [0.93191952],
#        [0.7727761 ],
#        [0.97315688],
#        [0.96830442],
#        [0.38417979],
#        [0.16629717],
#        [0.14996868],
#        [0.84190396],
#        [0.44994231],
#        [0.12161591],
#        [0.13671445],
#        [0.29122035],
#        [0.03797589],
#        [0.74520274],
#        [0.09302005],
#        [0.10096656],
#        [0.95382693],
#        [0.2744146 ]])

# %%
# 테스트를 수행할 모든 임곗값을 리스트 객체로 저장. 
thresholds = [0.4, 0.45, 0.50, 0.55, 0.60]

def get_eval_by_threshold(y_test , pred_proba_c1, thresholds):
    # thresholds 리스트 객체내의 값을 차례로 iteration하면서 Evaluation 수행.
    for custom_threshold in thresholds:
        binarizer = Binarizer(threshold=custom_threshold).fit(pred_proba_c1) 
        custom_predict = binarizer.transform(pred_proba_c1)
        print('\n임곗값:',custom_threshold)
        # roc_auc_score 관련 수정
        get_clf_eval(y_test , custom_predict, pred_proba_c1)

get_eval_by_threshold(y_test ,pred_proba[:,1].reshape(-1,1), thresholds )
# Out:
# 임곗값: 0.4
# 오차 행렬
# [[97 13]
#  [17 52]]
# 정확도: 0.8324, 정밀도: 0.8000, 재현율: 0.7536,    F1: 0.7761, AUC:0.8362
#
# 임곗값: 0.45
# 오차 행렬
# [[98 12]
#  [22 47]]
# 정확도: 0.8101, 정밀도: 0.7966, 재현율: 0.6812,    F1: 0.7344, AUC:0.8362
#
# 임곗값: 0.5
# 오차 행렬
# [[98 12]
#  [25 44]]
# 정확도: 0.7933, 정밀도: 0.7857, 재현율: 0.6377,    F1: 0.7040, AUC:0.8362
#
# 임곗값: 0.55
# 오차 행렬
# [[99 11]
#  [26 43]]
# 정확도: 0.7933, 정밀도: 0.7963, 재현율: 0.6232,    F1: 0.6992, AUC:0.8362
#
# 임곗값: 0.6
# 오차 행렬
# [[101   9]
#  [ 29  40]]
# 정확도: 0.7877, 정밀도: 0.8163, 재현율: 0.5797,    F1: 0.6780, AUC:0.8362

# %%
def precision_recall_curve_plot(y_test, pred_proba_c1):
    precisions, recalls, thresholds = precision_recall_curve(y_test, pred_proba_c1)
    
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary],  label='recall')
    
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1), 2))
    
    plt.xlabel('Threshold value');
    plt.ylabel('Precision and Recall value');
    plt.legend();
    plt.grid();
    plt.show();
    
precision_recall_curve_plot(y_test, est.predict_proba(X_test)[:,1].reshape(-1,1))

# %%
def roc_curve_plot(y_test , pred_proba_c1):
    # 임곗값에 따른 FPR, TPR 값을 반환 받음. 
    fprs , tprs , thresholds = roc_curve(y_test ,pred_proba_c1)

    # ROC Curve를 plot 곡선으로 그림. 
    plt.plot(fprs , tprs, label='ROC')
    # 가운데 대각선 직선을 그림. 
    plt.plot([0, 1], [0, 1], 'k--', label='Random')
    
    # FPR X 축의 Scale을 0.1 단위로 변경, X,Y 축명 설정등   
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    plt.xlim(0,1); plt.ylim(0,1)
    plt.xlabel('FPR( 1 - Sensitivity )'); plt.ylabel('TPR( Recall )')
    plt.legend()
    plt.show()
    
roc_curve_plot(y_test, est.predict_proba(X_test)[:, 1] )

# %% [markdown]
# ### 사용자 지정 metric

# %%
def mae_score(true, pred):
    score = np.mean(np.abs(true - pred))
    return score

# %% [markdown]
# # 스태킹
# * 개별모델로 각각 fit/predict 그 결과를 stacking
# * 최종 모델에 stacking fit/predict
#
# ** 최적화 파라미터 튜닝하고 적용**

# %%
# 최종 Stacking 모델을 위한 Classifier생성. 
lr_final = LogisticRegression(C=10)

# %% [markdown]
# ### Basic

# %%
"""

# 개별 모델들을 학습. 
knn_clf.fit(X_train, y_train)
rf_clf.fit(X_train , y_train)
dt_clf.fit(X_train , y_train)
ada_clf.fit(X_train, y_train)

# 학습된 개별 모델들이 각자 반환하는 예측 데이터 셋을 생성하고 개별 모델의 정확도 측정. 
knn_pred = knn_clf.predict(X_test)
rf_pred = rf_clf.predict(X_test)
dt_pred = dt_clf.predict(X_test)
ada_pred = ada_clf.predict(X_test)

print('KNN 정확도: {0:.4f}'.format(accuracy_score(y_test, knn_pred)))
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy_score(y_test, rf_pred)))
print('결정 트리 정확도: {0:.4f}'.format(accuracy_score(y_test, dt_pred)))
print('에이다부스트 정확도: {0:.4f} :'.format(accuracy_score(y_test, ada_pred)))

pred = np.array([knn_pred, rf_pred, dt_pred, ada_pred])
print(pred.shape)

# transpose를 이용해 행과 열의 위치 교환. 컬럼 레벨로 각 알고리즘의 예측 결과를 피처로 만듦. 
pred = np.transpose(pred)
print(pred.shape)

lr_final.fit(pred, y_test)
final = lr_final.predict(pred)

print('최종 메타 모델의 예측 정확도: {0:.4f}'.format(accuracy_score(y_test , final)))
"""
# Out:
# "\n\n# 개별 모델들을 학습. \nknn_clf.fit(X_train, y_train)\nrf_clf.fit(X_train , y_train)\ndt_clf.fit(X_train , y_train)\nada_clf.fit(X_train, y_train)\n\n# 학습된 개별 모델들이 각자 반환하는 예측 데이터 셋을 생성하고 개별 모델의 정확도 측정. \nknn_pred = knn_clf.predict(X_test)\nrf_pred = rf_clf.predict(X_test)\ndt_pred = dt_clf.predict(X_test)\nada_pred = ada_clf.predict(X_test)\n\nprint('KNN 정확도: {0:.4f}'.format(accuracy_score(y_test, knn_pred)))\nprint('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy_score(y_test, rf_pred)))\nprint('결정 트리 정확도: {0:.4f}'.format(accuracy_score(y_test, dt_pred)))\nprint('에이다부스트 정확도: {0:.4f} :'.format(accuracy_score(y_test, ada_pred)))\n\npred = np.array([knn_pred, rf_pred, dt_pred, ada_pred])\nprint(pred.shape)\n\n# transpose를 이용해 행과 열의 위치 교환. 컬럼 레벨로 각 알고리즘의 예측 결과를 피처로 만듦. \npred = np.transpose(pred)\nprint(pred.shape)\n\nlr_final.fit(pred, y_test)\nfinal = lr_final.predict(pred)\n\nprint('최종 메타 모델의 예측 정확도: {0:.4f}'.format(accuracy_score(y_test , final)))\n"

# %% [markdown]
# ### CV 셋 기반의 Stacking

# %%
# 개별 기반 모델에서 최종 메타 모델이 사용할 학습 및 테스트용 데이터를 생성하기 위한 함수. 
def get_stacking_base_datasets(model, X_train_n, y_train_n, X_test_n, n_folds ):
    # 지정된 n_folds값으로 KFold 생성.
    kf = KFold(n_splits=n_folds, shuffle=False, random_state=0)
    
    #추후에 메타 모델이 사용할 학습 데이터 반환을 위한 넘파이 배열 초기화 
    train_fold_pred = np.zeros((X_train_n.shape[0] ,1 ))
    test_pred = np.zeros((X_test_n.shape[0],n_folds))
    print(model.__class__.__name__ , ' model 시작 ')
    
    for folder_counter , (train_index, valid_index) in enumerate(kf.split(X_train_n)):
        #입력된 학습 데이터에서 기반 모델이 학습/예측할 폴드 데이터 셋 추출 
        print('\t 폴드 세트: ',folder_counter,' 시작 ')
        X_tr = X_train_n.iloc[train_index] 
        y_tr = y_train_n.iloc[train_index] 
        X_te = X_train_n.iloc[valid_index]  
        
        #폴드 세트 내부에서 다시 만들어진 학습 데이터로 기반 모델의 학습 수행.
        model.fit(X_tr , y_tr)
        
        #폴드 세트 내부에서 다시 만들어진 검증 데이터로 기반 모델 예측 후 데이터 저장.
        train_fold_pred[valid_index, :] = model.predict(X_te).reshape(-1,1)
        
        #입력된 원본 테스트 데이터를 폴드 세트내 학습된 기반 모델에서 예측 후 데이터 저장. 
        test_pred[:, folder_counter] = model.predict(X_test_n)
            
    # 폴드 세트 내에서 원본 테스트 데이터를 예측한 데이터를 평균하여 테스트 데이터로 생성 
    test_pred_mean = np.mean(test_pred, axis=1).reshape(-1,1)    
    
    #train_fold_pred는 최종 메타 모델이 사용하는 학습 데이터, test_pred_mean은 테스트 데이터
    return train_fold_pred , test_pred_mean

# %%
knn_train, knn_test = get_stacking_base_datasets(knn_clf, X_train, y_train, X_test, 7)
rf_train, rf_test = get_stacking_base_datasets(rf_clf, X_train, y_train, X_test, 7)
dt_train, dt_test = get_stacking_base_datasets(dt_clf, X_train, y_train, X_test,  7)    
ada_train, ada_test = get_stacking_base_datasets(ada_clf, X_train, y_train, X_test, 7)
# Out:
# KNeighborsClassifier  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작
# RandomForestClassifier  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작
# DecisionTreeClassifier  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작
# AdaBoostClassifier  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작

# %%
Stack_final_X_train = np.concatenate((knn_train, rf_train, dt_train, ada_train), axis=1)
Stack_final_X_test = np.concatenate((knn_test, rf_test, dt_test, ada_test), axis=1)
print('원본 학습 피처 데이터 Shape:',X_train.shape, '원본 테스트 피처 Shape:',X_test.shape)
print('스태킹 학습 피처 데이터 Shape:', Stack_final_X_train.shape,
      '스태킹 테스트 피처 데이터 Shape:',Stack_final_X_test.shape)
# Out:
# 원본 학습 피처 데이터 Shape: (712, 25) 원본 테스트 피처 Shape: (179, 25)
# 스태킹 학습 피처 데이터 Shape: (712, 4) 스태킹 테스트 피처 데이터 Shape: (179, 4)

# %%
lr_final.fit(Stack_final_X_train, y_train)
stack_final = lr_final.predict(Stack_final_X_test)

print('최종 메타 모델의 예측 정확도: {0:.4f}'.format(accuracy_score(y_test, stack_final)))
# Out:
# 최종 메타 모델의 예측 정확도: 0.8324

# %% [markdown]
# # 차원축소
# **피처가 많을 경우(특히 이미지, 텍스트)**
# * 피처 선택: 특정 피처만 선택
# * 피처 추출: 다른 공간으로 매핑 추출(잠재 요인)

# %% [markdown]
# ### PCA
# * 입력 데이터의 변동성이 가장 큰 축을 구하고
# * 그 축에 직각인 축을 반복적으로 축소하려는 차원 개수만큼 구해서
# * 입력 데이터를 새로운 차원에 투영
#
#
# * 입력 데이터의 공분산 행렬을 기반으로 고유벡터를 생성하고
# * 고유벡터에 데이터를 선현변환하는 방식

# %%
train.shape
# Out:
# (891, 25)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

#fit( )과 transform( ) 을 호출하여 PCA 변환 데이터 반환
pca.fit(train)
pca_data = pca.transform(train)
print(pca_data.shape)
# Out:
# (891, 2)

# %%
# PCA 변환된 데이터의 컬럼명을 각각 pca_component_1, pca_component_2로 명명
pca_columns=['pca_component_1','pca_component_2']
pca_df = pd.DataFrame(pca_data,columns=pca_columns)
pca_df['target']=target
pca_df.head(3)
# Out:
#    pca_component_1  pca_component_2  target
# 0        -7.552887        -0.604847       0
# 1         8.463103         1.339377       1
# 2        -3.551887        -0.819560       1

# %%
#setosa를 세모, versicolor를 네모, virginica를 동그라미로 표시
markers=['^', 's']

#pca_component_1 을 x축, pc_component_2를 y축으로 scatter plot 수행. 
for i, marker in enumerate(markers):
    x_axis_data = pca_df[pca_df['target']==i]['pca_component_1']
    y_axis_data = pca_df[pca_df['target']==i]['pca_component_2']
    plt.scatter(x_axis_data, y_axis_data, marker=marker,label=[0,1])

plt.legend()
plt.xlabel('pca_component_1')
plt.ylabel('pca_component_2')
plt.show()

# %%
# 각 PCA Component별 변동성 비율
print(pca.explained_variance_ratio_)
# Out:
# [0.97595736 0.00977479]

# %%
# PCA 변환된 데이터 세트로 분류 예측 성능
pca_X = pca_df[['pca_component_1', 'pca_component_2']]
scores_pca = cross_val_score(rf_clf, pca_X, target, scoring='accuracy', cv=3 )
print(scores_pca)
print(np.mean(scores_pca))
# Out:
# [0.66666667 0.7037037  0.71043771]
# 0.6936026936026934

# %% [markdown]
# ### LDA(Linear Discriminant Analysis)
# * 지도학습의 분류에서 사용하기 쉽도록 개별 클래스를 분별할 수 있는 기준 최대한 유지
#     * 클래스간 분산과 클래스 내부 분산의 비율 최대화

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=1)

lda.fit(train, target) # pca 에는 target 없음
lda_data = lda.transform(train)
print(lda_data.shape)
# Out:
# (891, 1)

# %% [markdown]
# **SVD와 NMF 는 매우 많은 피처 데이터를 가진 고차원 행렬을**
#
# **두개의 저차원 행렬로 분해하는 행렬분해 기법**

# %% [markdown]
# ### SVD(Singular Value Decomposition): 특이값 분해
# * PCA 가 정방행렬만 가능한 반면 크기가 다른 행렬도 가능
# * PCA 가 밀집행렬에만 가능한 반면 SVD는 희소 행렬에도 가능
# * 토픽 모델링 기법 LSA(Latent Semantic Analysis)의 기반 알고리즘
# * 이미지 압축, 패턴 인식, 신호처리 분야 등

# %%
from sklearn.decomposition import TruncatedSVD

# %%
tsvd = TruncatedSVD(n_components=2)
tsvd.fit(train)
tsvd_tf = tsvd.transform(train)

# %%
plt.scatter(x=tsvd_tf[:,0], y= tsvd_tf[:,1], c=target)
plt.xlabel('TruncatedSVD Component 1')
plt.ylabel('TruncatedSVD Component 2')
# Out:
# Text(0, 0.5, 'TruncatedSVD Component 2')

# %% [markdown]
# ### NMF(Non-Negative Matrix Factorization)
# **모든 원소 값이 양수가 보장되면 사용할 수 있는 근사 행렬 분해**
# * SVD와 유사
# * SVD 활용 분야 + 추천 영역(잠재 요소 기반 추천 방식)

# %%
from sklearn.decomposition import NMF

# %%
nmf = NMF(n_components=2)

nmf.fit(train)
nmf_tf = nmf.transform(train)

plt.scatter(x=nmf_tf[:,0], y= nmf_tf[:,1], c= target)
plt.xlabel('NMF Component 1')
plt.ylabel('NMF Component 2')
# Out:
# Text(0, 0.5, 'NMF Component 2')
