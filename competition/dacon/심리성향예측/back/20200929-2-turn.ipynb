# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

np.random.seed(42)

from sklearn.model_selection import train_test_split
import lightgbm as lgbm
from sklearn.metrics import confusion_matrix, accuracy_score

# %% [markdown]
# # 1. 데이터 로드

# %%
train=pd.read_csv('input/train.csv', index_col=0) #인덱스 col=0도 check!
test=pd.read_csv('input/test_x.csv', index_col=0)
submission=pd.read_csv('input/sample_submission.csv', index_col=0)

# %%
train.shape, test.shape, submission.shape

# %%
train.head(3)
test.head(3)
submission.head(3)

# %% [markdown]
# # 2. EDA & 전처리

# %%
df = pd.concat([train, test])
df.shape

# %%
train.info

# %% [markdown]
# ## Missing Value

# %%
train.isnull().sum().sum()
test.isnull().sum().sum()

# %% [markdown]
# ## Target 분포

# %%
f, ax = plt.subplots(1, 2, figsize=(10, 4))

train['voted'].value_counts().plot.pie(autopct='%1.1f%%', ax=ax[0], shadow=True)
sns.countplot('voted', data=train, ax=ax[1])

plt.show()

# 균일

# %% [markdown]
# ## Outlier

# %%
test.familysize.max(), test.familysize.mean(), train[train.familysize < 30]['familysize'].mean()

# %%
train[train.familysize > 20]['familysize'].value_counts().sort_values(ascending=False)

# %%
train.loc[train[train.familysize > 25].index, 'familysize'] = 2.6

# %%
train['familysize'].value_counts()

# %% [markdown]
# ## 인코딩

# %%
#age_group, gender, race, religion
train['age_group'] = train['age_group'].str.replace('s','').astype('int')
train['gender']= pd.factorize(train['gender'])[0]
train['race']=pd.factorize(train['race'])[0]
train['religion']=pd.factorize(train['religion'])[0]

test['age_group'] = test['age_group'].str.replace('s','').astype('int')
test['gender']=pd.factorize(test['gender'])[0]
test['race']=pd.factorize(test['race'])[0]
test['religion']=pd.factorize(test['religion'])[0]

# %% [markdown]
# ### One-hot

# %%
train = pd.get_dummies(train, columns=['age_group', 'education', 'engnat', 'gender', 'hand',
       'married', 'race', 'religion', 'tp01', 'tp02', 'tp03', 'tp04', 'tp05',
       'tp06', 'tp07', 'tp08', 'tp09', 'tp10', 'urban', 'wf_01',
       'wf_02', 'wf_03', 'wr_01', 'wr_02', 'wr_03', 'wr_04', 'wr_05', 'wr_06',
       'wr_07', 'wr_08', 'wr_09', 'wr_10', 'wr_11', 'wr_12', 'wr_13'])
train

# %%
test = pd.get_dummies(test, columns=['age_group', 'education', 'engnat', 'gender', 'hand',
       'married', 'race', 'religion', 'tp01', 'tp02', 'tp03', 'tp04', 'tp05',
       'tp06', 'tp07', 'tp08', 'tp09', 'tp10', 'urban', 'wf_01',
       'wf_02', 'wf_03', 'wr_01', 'wr_02', 'wr_03', 'wr_04', 'wr_05', 'wr_06',
       'wr_07', 'wr_08', 'wr_09', 'wr_10', 'wr_11', 'wr_12', 'wr_13'])
test

# %%
train.shape, test.shape
train.columns.values
test.columns.values

# %% [markdown]
# # 3. 모델 학습

# %%
from pycaret.classification import *

# %%
import gc
gc.collect()
# Out:
# 24

# %%
# %%time
clf = setup(data = train, target = 'voted', polynomial_features=True
           , categorical_features=['age_group','gender','race','religion'])
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# #T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row32_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row0_col1" class="data row0 col1" >3931</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row2_col1" class="data row2 col1" >1: 0, 2: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row3_col1" class="data row3 col1" >(45532, 77)</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row5_col1" class="data row5 col1" >41</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row6_col1" class="data row6 col1" >35</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row10_col1" class="data row10 col1" >(45532, 77)</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row11_col1" class="data row11 col1" >(31872, 214)</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row12_col1" class="data row12 col1" >(13660, 214)</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_af4c9a1e_01f9_11eb_a41b_00e0201808a0row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <
# Wall time: 34.5 s

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_a8a9e952_01fc_11eb_af52_00e0201808a0 th {
#           text-align: left;
#     }#T_a8a9e952_01fc_11eb_af52_00e0201808a0row0_col0,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row0_col3,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row0_col4,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row0_col5,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row1_col0,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row1_col1,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row1_col2,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row1_col3,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row1_col4,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row1_col5,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row1_col6,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row1_col7,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row2_col0,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row2_col1,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row2_col2,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row2_col3,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row2_col4,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row2_col5,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row2_col6,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row2_col7,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row3_col0,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row3_col1,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row3_col2,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row3_col3,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row3_col4,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row3_col6,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row3_col7,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row4_col0,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row4_col1,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row4_col2,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row4_col3,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row4_col4,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row4_col6,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row4_col7,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row5_col0,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row5_col1,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row5_col2,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row5_col3,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row5_col4,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row5_col5,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row5_col6,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row5_col7,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row6_col0,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row6_col1,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row6_col2,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row6_col3,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row6_col4,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row6_col5,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row6_col6,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row6_col7,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row7_col0,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row7_col1,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row7_col2,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row7_col3,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row7_col4,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row7_col5,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row7_col6,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row7_col7,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row8_col0,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row8_col1,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row8_col2,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row8_col3,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row8_col4,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row8_col5,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row8_col6,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row8_col7,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row9_col0,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row9_col1,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row9_col2,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row9_col3,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row9_col4,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row9_col5,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row9_col6,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row9_col7,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row10_col0,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row10_col1,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row10_col2,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row10_col3,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row10_col5,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row10_col6,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row10_col7,#T_a8a9e952_01fc_11 ...
#             text-align:  left;
#         }#T_a8a9e952_01fc_11eb_af52_00e0201808a0row0_col1,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row0_col2,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row0_col6,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row0_col7,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row3_col5,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row4_col5,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row10_col4,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row11_col3{
#             background-color:  yellow;
#             text-align:  left;
#         }#T_a8a9e952_01fc_11eb_af52_00e0201808a0row0_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row1_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row2_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row3_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row4_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row5_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row6_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row7_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row8_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row9_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row10_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row11_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row12_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row13_col8,#T_a8a9e952_01fc_11eb_af52_00e0201808a0row14_col8{
#             background-color:  lightgrey;
#             text-align:  left;
#         }</style><table id="T_a8a9e952_01fc_11eb_af52_00e0201808a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a8a9e952_01fc_11eb_af52_00e0201808a0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a8a9e952_01fc_11eb_af52_00e0201808a0row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_a8a9e952_01fc_11eb_af52_00e0201808a0row0_col1" class="data row0 col1" >0.6933
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=3931, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
#
#                                             Reference  Turbo
# ID
# lr            sklearn.linear_model.LogisticRegression   True
# knn            sklearn.neighbors.KNeighborsClassifier   True
# nb                     sklearn.naive_bayes.GaussianNB   True
# dt                sklearn.tree.DecisionTreeClassifier   True
# svm                sklearn.linear_model.SGDClassifier   True
# rbfsvm                                sklearn.svm.SVC  False
# gpc                      sklearn.gaussian_process.GPC  False
# mlp              sklearn.neural_network.MLPClassifier  False
# ridge            sklearn.linear_model.RidgeClassifier   True
# rf            sklearn.ensemble.RandomForestClassifier   True
# qda                 sklearn.discriminant_analysis.QDA   True
# ada               sklearn.ensemble.AdaBoostClassifier   True
# gbc       sklearn.ensemble.GradientBoostingClassifier   True
# lda                 sklearn.discriminant_analysis.LDA   True
# et              sklearn.ensemble.ExtraTreesClassifier   True
# xgboost                        xgboost.readthedocs.io   True
# lightgbm                github.com/microsoft/LightGBM   True
# catboost                                  catboost.ai   True

# %%
gbc  = create_model('gbc')
# Out:
# <style  type="text/css" >
# #T_0ac66902_01fe_11eb_83a4_00e0201808a0row10_col0,#T_0ac66902_01fe_11eb_83a4_00e0201808a0row10_col1,#T_0ac66902_01fe_11eb_83a4_00e0201808a0row10_col2,#T_0ac66902_01fe_11eb_83a4_00e0201808a0row10_col3,#T_0ac66902_01fe_11eb_83a4_00e0201808a0row10_col4,#T_0ac66902_01fe_11eb_83a4_00e0201808a0row10_col5,#T_0ac66902_01fe_11eb_83a4_00e0201808a0row10_col6{
#             background:  yellow;
#         }</style><table id="T_0ac66902_01fe_11eb_83a4_00e0201808a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0ac66902_01fe_11eb_83a4_00e0201808a0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row0_col0" class="data row0 col0" >0.6976</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row0_col1" class="data row0 col1" >0.7649</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row0_col2" class="data row0 col2" >0.6466</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row0_col3" class="data row0 col3" >0.7641</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row0_col4" class="data row0 col4" >0.7004</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row0_col5" class="data row0 col5" >0.3994</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row0_col6" class="data row0 col6" >0.4051</td>
#             </tr>
#             <tr>
#                         <th id="T_0ac66902_01fe_11eb_83a4_00e0201808a0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row1_col0" class="data row1 col0" >0.6948</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row1_col1" class="data row1 col1" >0.7611</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row1_col2" class="data row1 col2" >0.6351</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row1_col3" class="data row1 col3" >0.7666</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row1_col4" class="data row1 col4" >0.6947</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row1_col5" class="data row1 col5" >0.3949</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row1_col6" class="data row1 col6" >0.4019</td>
#             </tr>
#             <tr>
#                         <th id="T_0ac66902_01fe_11eb_83a4_00e0201808a0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row2_col0" class="data row2 col0" >0.6856</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row2_col1" class="data row2 col1" >0.7571</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row2_col2" class="data row2 col2" >0.6177</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row2_col3" class="data row2 col3" >0.7620</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row2_col4" class="data row2 col4" >0.6823</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row2_col5" class="data row2 col5" >0.3778</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row2_col6" class="data row2 col6" >0.3860</td>
#             </tr>
#             <tr>
#                         <th id="T_0ac66902_01fe_11eb_83a4_00e0201808a0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row3_col0" class="data row3 col0" >0.7016</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row3_col1" class="data row3 col1" >0.7714</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row3_col2" class="data row3 col2" >0.6510</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row3_col3" class="data row3 col3" >0.7678</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row3_col4" class="data row3 col4" >0.7046</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row3_col5" class="data row3 col5" >0.4072</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row3_col6" class="data row3 col6" >0.4129</td>
#             </tr>
#             <tr>
#                         <th id="T_0ac66902_01fe_11eb_83a4_00e0201808a0level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row4_col0" class="data row4 col0" >0.7113</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row4_col1" class="data row4 col1" >0.7805</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row4_col2" class="data row4 col2" >0.6546</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row4_col3" class="data row4 col3" >0.7820</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row4_col4" class="data row4 col4" >0.7127</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row4_col5" class="data row4 col5" >0.4272</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row4_col6" class="data row4 col6" >0.4340</td>
#             </tr>
#             <tr>
#                         <th id="T_0ac66902_01fe_11eb_83a4_00e0201808a0level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row5_col0" class="data row5 col0" >0.6909</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row5_col1" class="data row5 col1" >0.7545</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row5_col2" class="data row5 col2" >0.6397</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row5_col3" class="data row5 col3" >0.7575</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row5_col4" class="data row5 col4" >0.6936</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row5_col5" class="data row5 col5" >0.3863</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row5_col6" class="data row5 col6" >0.3919</td>
#             </tr>
#             <tr>
#                         <th id="T_0ac66902_01fe_11eb_83a4_00e0201808a0level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row6_col0" class="data row6 col0" >0.7057</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row6_col1" class="data row6 col1" >0.7796</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row6_col2" class="data row6 col2" >0.6586</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row6_col3" class="data row6 col3" >0.7700</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row6_col4" class="data row6 col4" >0.7100</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row6_col5" class="data row6 col5" >0.4149</td>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row6_col6" class="data row6 col6" >0.4201</td>
#             </tr>
#             <tr>
#                         <th id="T_0ac66902_01fe_11eb_83a4_00e0201808a0level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_0ac66902_01fe_11eb_83a4_00e0201808a0row7_co

# %%
tuned_gbc = tune_model(gbc)
# Out:
# <style  type="text/css" >
# #T_660c5f68_01ff_11eb_bd0f_00e0201808a0row10_col0,#T_660c5f68_01ff_11eb_bd0f_00e0201808a0row10_col1,#T_660c5f68_01ff_11eb_bd0f_00e0201808a0row10_col2,#T_660c5f68_01ff_11eb_bd0f_00e0201808a0row10_col3,#T_660c5f68_01ff_11eb_bd0f_00e0201808a0row10_col4,#T_660c5f68_01ff_11eb_bd0f_00e0201808a0row10_col5,#T_660c5f68_01ff_11eb_bd0f_00e0201808a0row10_col6{
#             background:  yellow;
#         }</style><table id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row0_col0" class="data row0 col0" >0.6835</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row0_col1" class="data row0 col1" >0.7554</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row0_col2" class="data row0 col2" >0.6695</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row0_col3" class="data row0 col3" >0.7294</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row0_col4" class="data row0 col4" >0.6982</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row0_col5" class="data row0 col5" >0.3668</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row0_col6" class="data row0 col6" >0.3683</td>
#             </tr>
#             <tr>
#                         <th id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row1_col0" class="data row1 col0" >0.6807</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row1_col1" class="data row1 col1" >0.7474</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row1_col2" class="data row1 col2" >0.6701</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row1_col3" class="data row1 col3" >0.7250</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row1_col4" class="data row1 col4" >0.6965</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row1_col5" class="data row1 col5" >0.3607</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row1_col6" class="data row1 col6" >0.3620</td>
#             </tr>
#             <tr>
#                         <th id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row2_col0" class="data row2 col0" >0.6768</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row2_col1" class="data row2 col1" >0.7387</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row2_col2" class="data row2 col2" >0.6590</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row2_col3" class="data row2 col3" >0.7247</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row2_col4" class="data row2 col4" >0.6903</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row2_col5" class="data row2 col5" >0.3540</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row2_col6" class="data row2 col6" >0.3557</td>
#             </tr>
#             <tr>
#                         <th id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row3_col0" class="data row3 col0" >0.6856</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row3_col1" class="data row3 col1" >0.7508</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row3_col2" class="data row3 col2" >0.6699</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row3_col3" class="data row3 col3" >0.7321</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row3_col4" class="data row3 col4" >0.6996</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row3_col5" class="data row3 col5" >0.3712</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row3_col6" class="data row3 col6" >0.3728</td>
#             </tr>
#             <tr>
#                         <th id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row4_col0" class="data row4 col0" >0.6869</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row4_col1" class="data row4 col1" >0.7582</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row4_col2" class="data row4 col2" >0.6701</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row4_col3" class="data row4 col3" >0.7341</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row4_col4" class="data row4 col4" >0.7007</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row4_col5" class="data row4 col5" >0.3738</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row4_col6" class="data row4 col6" >0.3755</td>
#             </tr>
#             <tr>
#                         <th id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row5_col0" class="data row5 col0" >0.6630</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row5_col1" class="data row5 col1" >0.7343</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row5_col2" class="data row5 col2" >0.6604</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row5_col3" class="data row5 col3" >0.7048</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row5_col4" class="data row5 col4" >0.6819</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row5_col5" class="data row5 col5" >0.3244</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row5_col6" class="data row5 col6" >0.3252</td>
#             </tr>
#             <tr>
#                         <th id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row6_col0" class="data row6 col0" >0.6916</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row6_col1" class="data row6 col1" >0.7627</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row6_col2" class="data row6 col2" >0.6862</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row6_col3" class="data row6 col3" >0.7328</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row6_col4" class="data row6 col4" >0.7087</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row6_col5" class="data row6 col5" >0.3817</td>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row6_col6" class="data row6 col6" >0.3827</td>
#             </tr>
#             <tr>
#                         <th id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_660c5f68_01ff_11eb_bd0f_00e0201808a0row7_co

# %%
lightgbm  = create_model('lightgbm') 
tuned_lightgbm = tune_model(lightgbm)
# Out:
# <style  type="text/css" >
# #T_681b1900_0200_11eb_b5ad_00e0201808a0row10_col0,#T_681b1900_0200_11eb_b5ad_00e0201808a0row10_col1,#T_681b1900_0200_11eb_b5ad_00e0201808a0row10_col2,#T_681b1900_0200_11eb_b5ad_00e0201808a0row10_col3,#T_681b1900_0200_11eb_b5ad_00e0201808a0row10_col4,#T_681b1900_0200_11eb_b5ad_00e0201808a0row10_col5,#T_681b1900_0200_11eb_b5ad_00e0201808a0row10_col6{
#             background:  yellow;
#         }</style><table id="T_681b1900_0200_11eb_b5ad_00e0201808a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_681b1900_0200_11eb_b5ad_00e0201808a0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row0_col0" class="data row0 col0" >0.6766</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row0_col1" class="data row0 col1" >0.7538</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row0_col2" class="data row0 col2" >0.6540</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row0_col3" class="data row0 col3" >0.7270</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row0_col4" class="data row0 col4" >0.6886</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row0_col5" class="data row0 col5" >0.3542</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row0_col6" class="data row0 col6" >0.3563</td>
#             </tr>
#             <tr>
#                         <th id="T_681b1900_0200_11eb_b5ad_00e0201808a0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row1_col0" class="data row1 col0" >0.6735</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row1_col1" class="data row1 col1" >0.7452</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row1_col2" class="data row1 col2" >0.6569</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row1_col3" class="data row1 col3" >0.7210</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row1_col4" class="data row1 col4" >0.6875</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row1_col5" class="data row1 col5" >0.3472</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row1_col6" class="data row1 col6" >0.3488</td>
#             </tr>
#             <tr>
#                         <th id="T_681b1900_0200_11eb_b5ad_00e0201808a0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row2_col0" class="data row2 col0" >0.6734</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row2_col1" class="data row2 col1" >0.7368</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row2_col2" class="data row2 col2" >0.6533</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row2_col3" class="data row2 col3" >0.7225</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row2_col4" class="data row2 col4" >0.6862</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row2_col5" class="data row2 col5" >0.3474</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row2_col6" class="data row2 col6" >0.3493</td>
#             </tr>
#             <tr>
#                         <th id="T_681b1900_0200_11eb_b5ad_00e0201808a0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row3_col0" class="data row3 col0" >0.6806</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row3_col1" class="data row3 col1" >0.7572</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row3_col2" class="data row3 col2" >0.6636</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row3_col3" class="data row3 col3" >0.7280</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row3_col4" class="data row3 col4" >0.6943</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row3_col5" class="data row3 col5" >0.3614</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row3_col6" class="data row3 col6" >0.3631</td>
#             </tr>
#             <tr>
#                         <th id="T_681b1900_0200_11eb_b5ad_00e0201808a0level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row4_col0" class="data row4 col0" >0.6840</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row4_col1" class="data row4 col1" >0.7583</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row4_col2" class="data row4 col2" >0.6690</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row4_col3" class="data row4 col3" >0.7306</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row4_col4" class="data row4 col4" >0.6984</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row4_col5" class="data row4 col5" >0.3680</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row4_col6" class="data row4 col6" >0.3695</td>
#             </tr>
#             <tr>
#                         <th id="T_681b1900_0200_11eb_b5ad_00e0201808a0level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row5_col0" class="data row5 col0" >0.6821</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row5_col1" class="data row5 col1" >0.7502</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row5_col2" class="data row5 col2" >0.6707</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row5_col3" class="data row5 col3" >0.7270</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row5_col4" class="data row5 col4" >0.6977</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row5_col5" class="data row5 col5" >0.3637</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row5_col6" class="data row5 col6" >0.3651</td>
#             </tr>
#             <tr>
#                         <th id="T_681b1900_0200_11eb_b5ad_00e0201808a0level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row6_col0" class="data row6 col0" >0.6803</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row6_col1" class="data row6 col1" >0.7565</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row6_col2" class="data row6 col2" >0.6781</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row6_col3" class="data row6 col3" >0.7207</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row6_col4" class="data row6 col4" >0.6988</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row6_col5" class="data row6 col5" >0.3588</td>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row6_col6" class="data row6 col6" >0.3595</td>
#             </tr>
#             <tr>
#                         <th id="T_681b1900_0200_11eb_b5ad_00e0201808a0level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_681b1900_0200_11eb_b5ad_00e0201808a0row7_co

# %%
catboost  = create_model('catboost') 
tuned_catboost = tune_model(catboost)
# Out:
# <style  type="text/css" >
# #T_65c4a9d4_0202_11eb_bedb_00e0201808a0row10_col0,#T_65c4a9d4_0202_11eb_bedb_00e0201808a0row10_col1,#T_65c4a9d4_0202_11eb_bedb_00e0201808a0row10_col2,#T_65c4a9d4_0202_11eb_bedb_00e0201808a0row10_col3,#T_65c4a9d4_0202_11eb_bedb_00e0201808a0row10_col4,#T_65c4a9d4_0202_11eb_bedb_00e0201808a0row10_col5,#T_65c4a9d4_0202_11eb_bedb_00e0201808a0row10_col6{
#             background:  yellow;
#         }</style><table id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row0_col0" class="data row0 col0" >0.6964</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row0_col1" class="data row0 col1" >0.7674</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row0_col2" class="data row0 col2" >0.6523</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row0_col3" class="data row0 col3" >0.7585</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row0_col4" class="data row0 col4" >0.7014</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row0_col5" class="data row0 col5" >0.3961</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row0_col6" class="data row0 col6" >0.4008</td>
#             </tr>
#             <tr>
#                         <th id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row1_col0" class="data row1 col0" >0.6907</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row1_col1" class="data row1 col1" >0.7595</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row1_col2" class="data row1 col2" >0.6472</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row1_col3" class="data row1 col3" >0.7525</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row1_col4" class="data row1 col4" >0.6959</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row1_col5" class="data row1 col5" >0.3849</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row1_col6" class="data row1 col6" >0.3894</td>
#             </tr>
#             <tr>
#                         <th id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row2_col0" class="data row2 col0" >0.6903</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row2_col1" class="data row2 col1" >0.7594</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row2_col2" class="data row2 col2" >0.6269</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row2_col3" class="data row2 col3" >0.7642</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row2_col4" class="data row2 col4" >0.6887</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row2_col5" class="data row2 col5" >0.3865</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row2_col6" class="data row2 col6" >0.3940</td>
#             </tr>
#             <tr>
#                         <th id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row3_col0" class="data row3 col0" >0.6963</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row3_col1" class="data row3 col1" >0.7713</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row3_col2" class="data row3 col2" >0.6493</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row3_col3" class="data row3 col3" >0.7601</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row3_col4" class="data row3 col4" >0.7003</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row3_col5" class="data row3 col5" >0.3963</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row3_col6" class="data row3 col6" >0.4013</td>
#             </tr>
#             <tr>
#                         <th id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row4_col0" class="data row4 col0" >0.7085</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row4_col1" class="data row4 col1" >0.7796</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row4_col2" class="data row4 col2" >0.6592</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row4_col3" class="data row4 col3" >0.7743</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row4_col4" class="data row4 col4" >0.7121</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row4_col5" class="data row4 col5" >0.4207</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row4_col6" class="data row4 col6" >0.4263</td>
#             </tr>
#             <tr>
#                         <th id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row5_col0" class="data row5 col0" >0.6922</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row5_col1" class="data row5 col1" >0.7546</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row5_col2" class="data row5 col2" >0.6483</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row5_col3" class="data row5 col3" >0.7543</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row5_col4" class="data row5 col4" >0.6973</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row5_col5" class="data row5 col5" >0.3878</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row5_col6" class="data row5 col6" >0.3924</td>
#             </tr>
#             <tr>
#                         <th id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row6_col0" class="data row6 col0" >0.7016</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row6_col1" class="data row6 col1" >0.7794</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row6_col2" class="data row6 col2" >0.6655</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row6_col3" class="data row6 col3" >0.7592</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row6_col4" class="data row6 col4" >0.7093</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row6_col5" class="data row6 col5" >0.4055</td>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row6_col6" class="data row6 col6" >0.4092</td>
#             </tr>
#             <tr>
#                         <th id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_65c4a9d4_0202_11eb_bedb_00e0201808a0row7_co

# %%
turn_3 = [tuned_gbc, tuned_lightgbm, tuned_catboost]

# %%
# %%time
best_3 = compare_models(sort = 'AUC', n_select = 3)

# %%
#blended = blend_models(estimator_list = best_3, fold = 5, method = 'soft')
blended = blend_models(estimator_list = turn_3, fold = 5, method = 'soft')
# Out:
# <style  type="text/css" >
# #T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col0,#T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col1,#T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col2,#T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col3,#T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col4,#T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col5,#T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col6{
#             background:  yellow;
#         }</style><table id="T_cfce9e74_0202_11eb_9689_00e0201808a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cfce9e74_0202_11eb_9689_00e0201808a0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row0_col0" class="data row0 col0" >0.6905</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row0_col1" class="data row0 col1" >0.7604</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row0_col2" class="data row0 col2" >0.6517</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row0_col3" class="data row0 col3" >0.7496</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row0_col4" class="data row0 col4" >0.6973</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row0_col5" class="data row0 col5" >0.3839</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row0_col6" class="data row0 col6" >0.3878</td>
#             </tr>
#             <tr>
#                         <th id="T_cfce9e74_0202_11eb_9689_00e0201808a0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row1_col0" class="data row1 col0" >0.6883</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row1_col1" class="data row1 col1" >0.7574</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row1_col2" class="data row1 col2" >0.6446</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row1_col3" class="data row1 col3" >0.7503</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row1_col4" class="data row1 col4" >0.6934</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row1_col5" class="data row1 col5" >0.3801</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row1_col6" class="data row1 col6" >0.3847</td>
#             </tr>
#             <tr>
#                         <th id="T_cfce9e74_0202_11eb_9689_00e0201808a0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row2_col0" class="data row2 col0" >0.6905</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row2_col1" class="data row2 col1" >0.7601</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row2_col2" class="data row2 col2" >0.6551</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row2_col3" class="data row2 col3" >0.7475</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row2_col4" class="data row2 col4" >0.6983</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row2_col5" class="data row2 col5" >0.3833</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row2_col6" class="data row2 col6" >0.3869</td>
#             </tr>
#             <tr>
#                         <th id="T_cfce9e74_0202_11eb_9689_00e0201808a0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row3_col0" class="data row3 col0" >0.6834</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row3_col1" class="data row3 col1" >0.7550</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row3_col2" class="data row3 col2" >0.6545</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row3_col3" class="data row3 col3" >0.7370</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row3_col4" class="data row3 col4" >0.6933</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row3_col5" class="data row3 col5" >0.3685</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row3_col6" class="data row3 col6" >0.3713</td>
#             </tr>
#             <tr>
#                         <th id="T_cfce9e74_0202_11eb_9689_00e0201808a0level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row4_col0" class="data row4 col0" >0.6801</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row4_col1" class="data row4 col1" >0.7533</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row4_col2" class="data row4 col2" >0.6483</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row4_col3" class="data row4 col3" >0.7354</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row4_col4" class="data row4 col4" >0.6891</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row4_col5" class="data row4 col5" >0.3624</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row4_col6" class="data row4 col6" >0.3654</td>
#             </tr>
#             <tr>
#                         <th id="T_cfce9e74_0202_11eb_9689_00e0201808a0level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col0" class="data row5 col0" >0.6866</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col1" class="data row5 col1" >0.7572</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col2" class="data row5 col2" >0.6508</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col3" class="data row5 col3" >0.7440</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col4" class="data row5 col4" >0.6943</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col5" class="data row5 col5" >0.3756</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row5_col6" class="data row5 col6" >0.3792</td>
#             </tr>
#             <tr>
#                         <th id="T_cfce9e74_0202_11eb_9689_00e0201808a0level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row6_col0" class="data row6 col0" >0.0041</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row6_col1" class="data row6 col1" >0.0028</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row6_col2" class="data row6 col2" >0.0040</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row6_col3" class="data row6 col3" >0.0064</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row6_col4" class="data row6 col4" >0.0033</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row6_col5" class="data row6 col5" >0.0087</td>
#                         <td id="T_cfce9e74_0202_11eb_9689_00e0201808a0row6_col6" class="data row6 col6" >0.0091</td>
#             </tr>
#     </tbody></table>

# %%
pred_holdout = predict_model(blended)
# Out:
#                Model  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Voting Classifier    0.6953  0.7672  0.6561  0.7547  0.7019  0.3934  0.3975

# %%
final_model = finalize_model(blended)

# %%
final_model

# %%
predictions = predict_model(final_model, data = test)

# %%
submission['voted'] = predictions['Score']

# %%
submission.to_csv('output/20200929-1.csv')

# %% [markdown]
# ## train, valid 데이터

# %%
X_train, X_test, y_train, y_test = train_test_split(train.drop('voted', axis = 1), train['voted'], test_size=0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %% [markdown]
# ## 하이퍼파라미터 튜닝

# %%
from bayes_opt import BayesianOptimization
from sklearn.metrics import roc_auc_score
from lightgbm import LGBMClassifier, plot_importance

# %% [markdown]
# colsample_bytree': 0.9606396547156734
# , 'max_bin': 164.7465545875555
# , 'max_depth': 11.107229265820779
# , 'min_child_samples': 198.98606348612637
# , 'min_child_weight': 41.32364031573033
# , 'num_leaves': 49.45519154750152
# , 'reg_alpha': 0.8758415725587487
# , 'reg_lambda': 8.299355787002883
# , 'subsample': 0.6598579157665245}}

# %%
# parameter 별로 search할 범위를 설정. 
bayesian_params = {
    'max_depth': (6, 16), 
    'num_leaves': (10, 100), 
    'min_child_samples': (10, 500), 
    'min_child_weight':(1, 100),
    'subsample':(0.1, 1.0),
    'colsample_bytree': (0.1, 1.0),
    'max_bin':(10, 1000),
    'reg_lambda':(0.001, 10),
    'reg_alpha': (0.01, 50) 
}

# %%
def lgb_roc_eval(max_depth, num_leaves, min_child_samples, min_child_weight, subsample, 
                colsample_bytree,max_bin, reg_lambda, reg_alpha):
    params = {
        #"n_estimators":500, "learning_rate":0.02,
        "n_estimators":1000, "learning_rate":0.001,
        'max_depth': int(round(max_depth)), #  호출 시 실수형 값이 들어오므로 정수형 하이퍼 파라미터는 정수형으로 변경 
        'num_leaves': int(round(num_leaves)), 
        'min_child_samples': int(round(min_child_samples)),
        'min_child_weight': int(round(min_child_weight)),
        'subsample': max(min(subsample, 1), 0), 
        'colsample_bytree': max(min(colsample_bytree, 1), 0),
        'max_bin':  max(int(round(max_bin)),10),
        'reg_lambda': max(reg_lambda,0),
        'reg_alpha': max(reg_alpha, 0)
    }
    lgb_model = LGBMClassifier(**params)
    lgb_model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    valid_proba = lgb_model.predict_proba(X_test)[:, 1]
    roc_auc = roc_auc_score(y_test, valid_proba)
    
    return roc_auc

# %%
import gc
gc.collect()

# %%
# %%time
# BayesianOptimization객체를 수행할 함수와 search할 parameter 범위를 설정하여 생성. 
lgbBO = BayesianOptimization(lgb_roc_eval,bayesian_params , random_state=42)
# 함수 반환값이 최대가 되는 입력값 유추를 위한 iteration 수행. 
lgbBO.maximize(init_points=10, n_iter=50)

# %%
target_list = []
for result in lgbBO.res:
    target = result['target']
    target_list.append(target)
print(target_list)
# 가장 큰 target 값을 가지는 순번(index)를 추출
print('maximum target index:', np.argmax(np.array(target_list)))

# 가장 큰 target값을 가지는 index값을 기준으로 res에서 해당 parameter 추출. 
max_dict = lgbBO.res[np.argmax(np.array(target_list))]
print(max_dict)

# %% [markdown]
# * test_size=0.3
# {'target': 0.7655615473679408, 'params': {'colsample_bytree': 0.737265320016441, 'max_bin': 30.378649352844423, 'max_depth': 15.699098521619943, 'min_child_samples': 417.8968939922066, 'min_child_weight': 22.02157195714934, 'num_leaves': 26.364247048639054, 'reg_alpha': 9.178391447573157, 'reg_lambda': 3.043118187352418, 'subsample': 0.5722807884690141}}
#
# - outlier 삭제
# {'target': 0.7652209584768751, 'params': {'colsample_bytree': 0.5703824815639528, 'max_bin': 15.404309116854074, 'max_depth': 13.17919661428763, 'min_child_samples': 24.998278489695448, 'min_child_weight': 97.74061068693372, 'num_leaves': 99.35614131954165, 'reg_alpha': 1.2926370490809749, 'reg_lambda': 1.1059679925299122, 'subsample': 0.4274854420066033}}
#
# - outlier 2.6
# {'target': 0.7655617202045278, 'params': {'colsample_bytree': 0.737265320016441, 'max_bin': 30.378649352844423, 'max_depth': 15.699098521619943, 'min_child_samples': 417.8968939922066, 'min_child_weight': 22.02157195714934, 'num_leaves': 26.364247048639054, 'reg_alpha': 9.178391447573157, 'reg_lambda': 3.043118187352418, 'subsample': 0.5722807884690141}}

# %%
clf = LGBMClassifier(
        n_jobs=-1
        ,nthread=4
        ,n_estimators=1000
        ,learning_rate=0.02
        ,max_depth = 16
        ,num_leaves=47
        ,colsample_bytree=0.56
        ,subsample=0.55
        ,max_bin=30
        ,reg_alpha=0.23
        ,reg_lambda=0.03
        ,min_child_weight=70
        ,min_child_samples=169
        ,silent=-1
        ,verbose=-1
        ,random_state=42
        )

clf.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], 
eval_metric= 'auc', verbose= 100, early_stopping_rounds= 50)

# %%
plot_importance(clf, figsize=(16, 32))

# %% [markdown]
# # 4. 예측

# %%
pred_y  = clf.predict(test)

# %%
submission['voted'] = pred_y

# %%
submission

# %% [markdown]
# # 5. 제출

# %%
submission.to_csv('output/20200928-1.csv')
