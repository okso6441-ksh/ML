# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from tqdm import tqdm
import gc
import random

import lightgbm as lgb
import re
from sklearn.metrics import *
from sklearn.model_selection import KFold

import warnings
warnings.filterwarnings(action='ignore')

from pycaret.classification import *

import random as python_random
seed = 42
np.random.seed(seed)
python_random.seed(seed)
set_config('seed', seed)

# %%
PATH = './data/'

train_err  = pd.read_csv(PATH+'train_err_data.csv')
train_qua = pd.read_csv(PATH+'train_quality_data.csv')
train_prob = pd.read_csv(PATH+'train_problem_data.csv')

test_err  = pd.read_csv(PATH+'test_err_data.csv')
test_qua  = pd.read_csv(PATH+'test_quality_data.csv')

sample_submssion = pd.read_csv(PATH+'sample_submission.csv')

# %%
def chg_qua(x):
    if x == 0:
        return 0
    else:
        return 1

# %%
train_err['date'] = train_err['time'].astype(str).str.slice(0,8)
train_err['model_fwver'] = train_err.model_nm + train_err.fwver
train_err['errtype_code'] = train_err.errtype.astype(str) + train_err.errcode

train_err_0 = train_err[['user_id','date','model_fwver','errtype_code']].drop_duplicates()
display(train_err_0.head())

test_err['date'] = test_err['time'].astype(str).str.slice(0,8)
test_err['model_fwver'] = test_err.model_nm + test_err.fwver
test_err['errtype_code'] = test_err.errtype.astype(str) + test_err.errcode

test_err_0 = test_err[['user_id','date','model_fwver','errtype_code']].drop_duplicates()
display(test_err_0.head())
# Out:
#    user_id      date        model_fwver errtype_code
# 0    10000  20201101  model_305.15.2138          151
# 1    10000  20201101  model_305.15.2138          121
# 2    10000  20201101  model_305.15.2138          111
# 3    10000  20201101  model_305.15.2138          161
# 4    10000  20201101  model_305.15.2138           40
#    user_id      date        model_fwver errtype_code
# 0    30000  20201101  model_104.16.3553          311
# 1    30000  20201101  model_104.16.3553          332
# 2    30000  20201101  model_104.16.3553          151
# 3    30000  20201101  model_104.16.3553          221
# 4    30000  20201101  model_104.16.3553          111

# %%
train_err_1 = train_err.groupby(['user_id','date']).count().reset_index()[['user_id','date','time']]
train_err_1.columns = ['user_id','date','date_cnt']
train_err_1 = train_err_1.groupby('user_id').agg({'date':'count','date_cnt': 'sum'}).reset_index()
train_err_1.columns = ['user_id','date_cnt', 'date_sum']
display(train_err_1.head())

test_err_1 = test_err.groupby(['user_id','date']).count().reset_index()[['user_id','date','time']]
test_err_1.columns = ['user_id','date','date_cnt']
test_err_1 = test_err_1.groupby('user_id').agg({'date':'count','date_cnt': 'sum'}).reset_index()
test_err_1.columns = ['user_id','date_cnt', 'date_sum']
display(test_err_1.head())

train_err_1.shape

# %%
train = train_err_1.copy()
test = test_err_1.copy()

# %%
train_model = set(train_err.model_fwver.unique())
test_model = set(test_err.model_fwver.unique())
models = train_model & test_model
models = list(models)

for model in models:
    train[model] = 0
    test[model] = 0
    
train.shape, test.shape

# %%
train_err_2 = train_err.groupby(['user_id','model_fwver']).count().reset_index()[['user_id','model_fwver','time']]
train_err_2.columns = ['user_id','model_fwver','model_fwver_cnt']
display(train_err_2.head())

test_err_2 = test_err.groupby(['user_id','model_fwver']).count().reset_index()[['user_id','model_fwver','time']]
test_err_2.columns = ['user_id','model_fwver','model_fwver_cnt']
display(test_err_2.head())

# %%
for idx, col in tqdm(enumerate(train_err_2.values)):
    i = train[train.user_id == train_err_2.loc[idx].user_id].index
    c = train.columns[train.columns == train_err_2.loc[idx].model_fwver]
    
    train.loc[i, c] += train_err_2.loc[idx].model_fwver_cnt    

for idx, col in tqdm(enumerate(test_err_2.values)):
    i = test[test.user_id == test_err_2.loc[idx].user_id].index
    c = test.columns[test.columns == test_err_2.loc[idx].model_fwver]
    
    test.loc[i, c] += test_err_2.loc[idx].model_fwver_cnt

# %%
train_error = set(train_err.errtype.unique())
test_error = set(test_err.errtype.unique())
errors = train_error & test_error
errors = list(errors)

for error in errors:
    train['E'+str(error)] = 0
    test['E'+str(error)] = 0
    
train.shape, test.shape

# %%
train_err_3 = train_err.groupby(['user_id','errtype']).count().reset_index()[['user_id','errtype','time']]
train_err_3.columns = ['user_id','errtype','errtype_cnt']
display(train_err_3.head())

test_err_3 = test_err.groupby(['user_id','errtype']).count().reset_index()[['user_id','errtype','time']]
test_err_3.columns = ['user_id','errtype','errtype_cnt']
display(test_err_3.head())

# %%
for idx, col in tqdm(enumerate(train_err_3.values)):
    i = train[train.user_id == train_err_3.loc[idx].user_id].index
    c = train.columns[train.columns == 'E'+str(train_err_3.loc[idx].errtype)]
    
    train.loc[i, c] += train_err_3.loc[idx].errtype_cnt    

for idx, col in tqdm(enumerate(test_err_3.values)):
    i = test[test.user_id == test_err_3.loc[idx].user_id].index
    c = test.columns[test.columns == 'E'+str(test_err_3.loc[idx].errtype)]
    
    test.loc[i, c] += test_err_3.loc[idx].errtype_cnt

# %%
train_qua_0 = train_qua.drop_duplicates()
test_qua_0 = test_qua.drop_duplicates()

train_qua_0.drop(['quality_3','quality_4','time','fwver'], axis=1, inplace=True)
test_qua_0.drop(['quality_3','quality_4','time','fwver'], axis=1, inplace=True)

train_qua_0.fillna(0, inplace=True)
test_qua_0.fillna(0, inplace=True)

# %%
cols = ['quality_0', 'quality_1', 'quality_2', 'quality_5','quality_6', 'quality_7', 'quality_8', 'quality_9', 'quality_10','quality_11', 'quality_12']

for col in cols:
    train_qua_0[col] = train_qua_0[col].apply(chg_qua)
    test_qua_0[col] = test_qua_0[col].apply(chg_qua)

# %%
train_qua_1 = train_qua_0.groupby('user_id').sum().reset_index()
test_qua_1 = test_qua_0.groupby('user_id').sum().reset_index()

# %%
train = train.merge(train_qua_1, on='user_id', how='left').fillna(0)
test = test.merge(test_qua_1, on='user_id', how='left').fillna(0)

# %%
train.to_csv("./train.csv", index=False)
test.to_csv("./test.csv", index=False)

# %%
train  = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
display(train.head())
display(test.head())

train.shape, test.shape

# %%
train_err_d1 = train_err.groupby(['user_id','date']).count().groupby('user_id')['time'].max().reset_index()
train_err_d1.columns = ['user_id', 'day_max']
train_err_d1
# Out:
#        user_id  day_max
# 0        10000       20
# 1        10001     1452
# 2        10002       17
# 3        10003       24
# 4        10004      102
# ...        ...      ...
# 14995    24995       30
# 14996    24996        4
# 14997    24997       64
# 14998    24998       37
# 14999    24999       30
#
# [15000 rows x 2 columns]

# %%
test_err_d1 = test_err.groupby(['user_id','date']).count().groupby('user_id')['time'].max().reset_index()
test_err_d1.columns = ['user_id', 'day_max']
test_err_d1
# Out:
#        user_id  day_max
# 0        30000      808
# 1        30001       22
# 2        30002       67
# 3        30003       75
# 4        30004       85
# ...        ...      ...
# 14993    44994       90
# 14994    44995       35
# 14995    44996      430
# 14996    44997     2606
# 14997    44998      104
#
# [14998 rows x 2 columns]

# %%
train = train.merge(train_err_d1, on='user_id', how='left')
test = test.merge(test_err_d1, on='user_id', how='left')
train
# Out:
#        user_id  date_cnt  date_sum  model_403.11.1167  model_804.73.2571  \
# 0        10000        30       317                  0                  0
# 1        10001        30      2365                  0                  0
# 2        10002        29       306                  0                  0
# 3        10003        30       306                  0                  0
# 4        10004        30       777                  0                  0
# ...        ...       ...       ...                ...                ...
# 14995    24995        10       194                  0                  0
# 14996    24996         1         4                  0                  0
# 14997    24997        30       826                  0                  0
# 14998    24998        21       155                  0                  0
# 14999    24999        30       570                  0                  0
#
#        model_004.22.1750  model_610  model_68.5.3  model_204.33.1185  \
# 0                      0          0             0                  0
# 1                      0          0             0                379
# 2                      0          0             0                  0
# 3                      0          0             0                 81
# 4                    645          0             0                  0
# ...                  ...        ...           ...                ...
# 14995                  0          0             0                  0
# 14996                  0          0             0                  0
# 14997                465          0             0                  0
# 14998                  8          0             0                  0
# 14999                  0          0             0                  0
#
#        model_705.66.3237  ...  quality_2  quality_5  quality_6  quality_7  \
# 0                      0  ...          0          4          0          4
# 1                      0  ...          0          0          0          0
# 2                      0  ...          2         22          4         22
# 3                      0  ...          0          0          0          0
# 4                      0  ...          1          6          2          6
# ...                  ...  ...        ...        ...        ...        ...
# 14995                  0  ...          2          6          2          0
# 14996                  0  ...          0          0          0          0
# 14997                  0  ...          1          8          1          0
# 14998                  0  ...          0          0          0          0
# 14999                  0  ...          0          0          0          0
#
#        quality_8  quality_9  quality_10  quality_11  quality_12  day_max
# 0              0          4           4           0           0       20
# 1              0          0           0           0           0     1452
# 2              0         22          22           1           0       17
# 3              0          0           0           0           0       24
# 4              0          6           6           1           0      102
# ...          ...        ...         ...         ...         ...      ...
# 14995          0          0           6           2           0       30
# 14996          0          0           0           0           0        4
# 14997          0          0           8           1           0       64
# 14998          0          0           0           0           0       37
# 14999          0          0           0           0           0       30
#
# [15000 rows x 87 columns]

# %%
col = ['E31']
idx = train[col].sort_values(by=col, ascending=False)[:10].index
cols = list(col)
cols.append('prob')
train.loc[idx, cols]

# %%
idx = test[col].sort_values(by=col, ascending=False)[:5].index
test.loc[idx, col]

# %%
train.loc[train['model_305.15.2138'] > 50000,'model_305.15.2138'] = 50000
test.loc[test['model_305.15.2138'] > 50000,'model_305.15.2138'] = 50000

train.loc[train['model_403.11.1167'] > 100000,'model_403.11.1167'] = 100000
test.loc[test['model_403.11.1167'] > 100000,'model_403.11.1167'] = 100000

train.loc[train['model_610'] > 60,'model_610'] = 60
test.loc[test['model_610'] > 60,'model_610'] = 60

# %%
cols = ['model_68.5.3', 'model_504.82.1730','model_403.11.1149', 'model_305.15.2092','model_004.22.1656', 'model_305.15.2114']


train.drop(cols, axis=1, inplace=True)
test.drop(cols, axis=1, inplace=True)

# %%
for col in cols:
    sns.boxplot(test[col])
    plt.show()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(train.corr(), annot=True, fmt='.2f', cmap='RdYlGn_r')

# %%
test.columns

# %%
train

# %%
test.info()

# %%
train_prob1 = train_prob.groupby('user_id').count().reset_index()
train_prob1.time = train_prob1.time.apply(chg_qua)
train_prob1.columns = ['user_id', 'prob']
train_prob1
# Out:
#       user_id  prob
# 0       10001     1
# 1       10004     1
# 2       10005     1
# 3       10006     1
# 4       10008     1
# ...       ...   ...
# 4995    24983     1
# 4996    24984     1
# 4997    24990     1
# 4998    24997     1
# 4999    24998     1
#
# [5000 rows x 2 columns]

# %%
train = train.merge(train_prob1, on='user_id', how='left').fillna(0)
train
# Out:
#        user_id  date_cnt  date_sum  model_403.11.1167  model_804.73.2571  \
# 0        10000        30       317                  0                  0
# 1        10001        30      2365                  0                  0
# 2        10002        29       306                  0                  0
# 3        10003        30       306                  0                  0
# 4        10004        30       777                  0                  0
# ...        ...       ...       ...                ...                ...
# 14995    24995        10       194                  0                  0
# 14996    24996         1         4                  0                  0
# 14997    24997        30       826                  0                  0
# 14998    24998        21       155                  0                  0
# 14999    24999        30       570                  0                  0
#
#        model_004.22.1750  model_610  model_204.33.1185  model_705.66.3237  \
# 0                      0          0                  0                  0
# 1                      0          0                379                  0
# 2                      0          0                  0                  0
# 3                      0          0                 81                  0
# 4                    645          0                  0                  0
# ...                  ...        ...                ...                ...
# 14995                  0          0                  0                  0
# 14996                  0          0                  0                  0
# 14997                465          0                  0                  0
# 14998                  8          0                  0                  0
# 14999                  0          0                  0                  0
#
#        model_104.16.3571  ...  quality_5  quality_6  quality_7  quality_8  \
# 0                      0  ...          4          0          4          0
# 1                      0  ...          0          0          0          0
# 2                      0  ...         22          4         22          0
# 3                      0  ...          0          0          0          0
# 4                      0  ...          6          2          6          0
# ...                  ...  ...        ...        ...        ...        ...
# 14995                  0  ...          6          2          0          0
# 14996                  0  ...          0          0          0          0
# 14997                  0  ...          8          1          0          0
# 14998                  0  ...          0          0          0          0
# 14999                  0  ...          0          0          0          0
#
#        quality_9  quality_10  quality_11  quality_12  day_max  prob
# 0              4           4           0           0       20   0.0
# 1              0           0           0           0     1452   1.0
# 2             22          22           1           0       17   0.0
# 3              0           0           0           0       24   0.0
# 4              6           6           1           0      102   1.0
# ...          ...         ...         ...         ...      ...   ...
# 14995          0           6           2           0       30   0.0
# 14996          0           0           0           0        4   0.0
# 14997          0           8           1           0       64   1.0
# 14998          0           0           0           0       37   1.0
# 14999          0           0           0           0       30   0.0
#
# [15000 rows x 82 columns]

# %%
train.prob = train.prob.astype(int)

# %%
train.info()

# %%
train.columns[1:-1]

# %%
# %%time
clf = setup(session_id=seed, data=train, target='prob'
           , numeric_features=train.columns[1:-1])
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row0_col1" class="data row0 col1" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row3_col1" class="data row3 col1" >(15000, 82)</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row5_col1" class="data row5 col1" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row10_col1" class="data row10 col1" >(15000, 82)</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row11_col1" class="data row11 col1" >(10499, 80)</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row12_col1" class="data row12 col1" >(4501, 80)</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_481d8edc_61ec_11eb_a8ec_00e0201808a0row18_col1" class="data row18 col1" >None</td>
#             </tr>
# Wall time: 6.57 s

# %%
best = compare_models(sort = 'AUC', n_select = 5
                     ,exclude=['lr', 'knn', 'nb', 'dt', 'svm', 'rbfsvm', 'ridge','qda']
                     )
# Out:
# <style  type="text/css" >
#     #T_fdb78cfa_61ed_11eb_8720_00e0201808a0 th {
#           text-align: left;
#     }#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col0,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col3,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col4,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col0,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col1,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col2,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col3,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col5,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col6,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col7,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col0,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col1,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col2,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col3,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col4,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col5,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col6,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col7,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row3_col0,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row3_col1,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row3_col2,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row3_col3,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row3_col4,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row3_col5,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row3_col6,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row3_col7,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row4_col0,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row4_col1,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row4_col2,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row4_col3,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row4_col4,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row4_col5,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row4_col6,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row4_col7,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row5_col0,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row5_col1,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row5_col2,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row5_col4,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row5_col5,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row5_col6,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row5_col7,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row6_col0,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row6_col1,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row6_col2,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row6_col3,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row6_col4,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row6_col5,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row6_col6,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row6_col7,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row7_col0,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row7_col1,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row7_col2,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row7_col3,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row7_col4,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row7_col5,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row7_col6,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row7_col7{
#             text-align:  left;
#         }#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col1,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col2,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col5,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col6,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col7,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col4,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row5_col3{
#             background-color:  yellow;
#             text-align:  left;
#         }#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col8,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col8,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col8,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row3_col8,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row4_col8,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row5_col8,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row6_col8,#T_fdb78cfa_61ed_11eb_8720_00e0201808a0row7_col8{
#             background-color:  lightgrey;
#             text-align:  left;
#         }</style><table id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col1" class="data row0 col1" >0.7955</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col2" class="data row0 col2" >0.8180</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col3" class="data row0 col3" >0.5091</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col4" class="data row0 col4" >0.8064</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col5" class="data row0 col5" >0.6240</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col6" class="data row0 col6" >0.4932</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col7" class="data row0 col7" >0.5180</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row0_col8" class="data row0 col8" >21.8509</td>
#             </tr>
#             <tr>
#                         <th id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col1" class="data row1 col1" >0.7900</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col2" class="data row1 col2" >0.8153</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col3" class="data row1 col3" >0.4786</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col4" class="data row1 col4" >0.8153</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col5" class="data row1 col5" >0.6028</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col6" class="data row1 col6" >0.4730</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col7" class="data row1 col7" >0.5042</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row1_col8" class="data row1 col8" >6.8205</td>
#             </tr>
#             <tr>
#                         <th id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col1" class="data row2 col1" >0.7903</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col2" class="data row2 col2" >0.8123</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col3" class="data row2 col3" >0.5157</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col4" class="data row2 col4" >0.7810</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col5" class="data row2 col5" >0.6211</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col6" class="data row2 col6" >0.4844</td>
#                         <td id="T_fdb78cfa_61ed_11eb_8720_00e0201808a0row2_col7"

# %%
blended = blend_models(estimator_list = best, fold = 5, method = 'soft')
# Out:
# <style  type="text/css" >
# #T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col0,#T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col1,#T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col2,#T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col3,#T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col4,#T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col5,#T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col6{
#             background:  yellow;
#         }</style><table id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row0_col0" class="data row0 col0" >0.7786</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row0_col1" class="data row0 col1" >0.8088</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row0_col2" class="data row0 col2" >0.4729</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row0_col3" class="data row0 col3" >0.7752</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row0_col4" class="data row0 col4" >0.5874</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row0_col5" class="data row0 col5" >0.4480</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row0_col6" class="data row0 col6" >0.4735</td>
#             </tr>
#             <tr>
#                         <th id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row1_col0" class="data row1 col0" >0.8081</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row1_col1" class="data row1 col1" >0.8312</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row1_col2" class="data row1 col2" >0.5257</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row1_col3" class="data row1 col3" >0.8383</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row1_col4" class="data row1 col4" >0.6462</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row1_col5" class="data row1 col5" >0.5238</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row1_col6" class="data row1 col6" >0.5507</td>
#             </tr>
#             <tr>
#                         <th id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row2_col0" class="data row2 col0" >0.7929</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row2_col1" class="data row2 col1" >0.8192</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row2_col2" class="data row2 col2" >0.4943</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row2_col3" class="data row2 col3" >0.8103</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row2_col4" class="data row2 col4" >0.6140</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row2_col5" class="data row2 col5" >0.4836</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row2_col6" class="data row2 col6" >0.5112</td>
#             </tr>
#             <tr>
#                         <th id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row3_col0" class="data row3 col0" >0.8029</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row3_col1" class="data row3 col1" >0.8332</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row3_col2" class="data row3 col2" >0.4971</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row3_col3" class="data row3 col3" >0.8488</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row3_col4" class="data row3 col4" >0.6270</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row3_col5" class="data row3 col5" >0.5052</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row3_col6" class="data row3 col6" >0.5386</td>
#             </tr>
#             <tr>
#                         <th id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row4_col0" class="data row4 col0" >0.7813</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row4_col1" class="data row4 col1" >0.7992</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row4_col2" class="data row4 col2" >0.4843</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row4_col3" class="data row4 col3" >0.7757</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row4_col4" class="data row4 col4" >0.5963</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row4_col5" class="data row4 col5" >0.4571</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row4_col6" class="data row4 col6" >0.4810</td>
#             </tr>
#             <tr>
#                         <th id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col0" class="data row5 col0" >0.7927</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col1" class="data row5 col1" >0.8183</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col2" class="data row5 col2" >0.4949</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col3" class="data row5 col3" >0.8097</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col4" class="data row5 col4" >0.6142</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col5" class="data row5 col5" >0.4835</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row5_col6" class="data row5 col6" >0.5110</td>
#             </tr>
#             <tr>
#                         <th id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row6_col0" class="data row6 col0" >0.0116</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row6_col1" class="data row6 col1" >0.0130</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row6_col2" class="data row6 col2" >0.0176</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row6_col3" class="data row6 col3" >0.0306</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row6_col4" class="data row6 col4" >0.0211</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row6_col5" class="data row6 col5" >0.0285</td>
#                         <td id="T_6e44d33a_61ee_11eb_8dfe_00e0201808a0row6_col6" class="data row6 col6" >0.0305</td>
#             </tr>
#     </tbody></table>

# %%
pred_holdout = predict_model(blended)
# Out:
#                Model  Accuracy     AUC  Recall   Prec.     F1   Kappa     MCC
# 0  Voting Classifier    0.7903  0.8195   0.486  0.8082  0.607  0.4758  0.5044

# %%
# %%time
final_model = finalize_model(blended)

# %%
test_x = sample_submssion[['user_id']].merge(test, on='user_id', how='left').fillna(0)
test_x.shape

# %%
predictions = predict_model(final_model, data = test_x)

# %%
sample_submssion['problem'] = predictions['Score']
sample_submssion.head()

# %%
sample_submssion.to_csv("./submission/submission_20210129-3.csv", index = False)
sample_submssion
